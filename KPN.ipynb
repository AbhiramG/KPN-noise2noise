# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from skimage.color import rgb2gray
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
from torchvision import transforms, utils
import os
import numpy as np
from os import walk
import torch.optim as optim

# %%
class KPN(nn.Module):
    def __init__(self, device,burst_len = 1, K = 5):
        super(KPN, self).__init__()
        
        self.device = device
        self.K = K
        self.burst_len = burst_len
        self.conv_start = nn.Conv2d(burst_len,64,3,padding=1)
        self.conv_end = nn.Conv2d(64,burst_len,3,padding=1)
        
        self.batchnorm64 = nn.BatchNorm2d(64)
        self.batchnorm128 = nn.BatchNorm2d(128)
        self.batchnorm256 = nn.BatchNorm2d(256)
        self.batchnorm512 = nn.BatchNorm2d(512)
        self.batchnormK2N = nn.BatchNorm2d(K**2 * burst_len)
        
        
        self.conv_64to128 = nn.Conv2d(64,128,3,padding=1)
        self.conv_128to256 = nn.Conv2d(128,256,3,padding=1)
        self.conv_256to512 = nn.Conv2d(256,512,3,padding=1)
        self.conv_512to256 = nn.Conv2d(512,256,3,padding=1)
        self.conv_256to128 = nn.Conv2d(256,128,3,padding=1)
        self.conv_128toK2N = nn.Conv2d(128,K**2 * burst_len,3,padding=1)
        
        
        self.conv_64 = nn.Conv2d(64,64,3,padding=1)
        self.conv_128 = nn.Conv2d(128,128,3,padding=1)
        self.conv_256 = nn.Conv2d(256,256,3,padding=1)
        self.conv_512 = nn.Conv2d(512,512,3,padding=1)
        self.conv_K2N = nn.Conv2d(K**2 * burst_len,K**2 * burst_len,3,padding=1)
        
        self.avg_pool_downsample = nn.AvgPool2d(2,2)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear')
        
        
    def custom_block(self,conv1, conv2, x,bn):
        x = conv1(x)
        x = F.relu(x)
        x = bn(x)
        x = conv2(x)
        x = F.relu(x)
        x = bn(x)
        x = conv2(x)
        x = F.relu(x)
        x = bn(x)
        
        return x
        
    def custom_block_res(self,conv1, conv2, x, y,bn):
        x = conv1(x)
        x = F.relu(x)
        x = bn(x)
        x = x + y
        x = conv2(x)
        x = F.relu(x)
        x = bn(x)
        x = conv2(x)
        x = F.relu(x)
        x = bn(x)
        
        return x
    
    def custom_block_res2(self,conv1, conv2, conv3, x, y,bn1,bn2):
        x = conv1(x)
        x = F.relu(x)
        x = bn1(x)
        x = x + y
        x = conv2(x)
        x = F.relu(x)
        x = bn2(x)
        x = conv3(x)
        x = bn2(x)
        
        return x
    
    def convolve(self,filt,x,K):
        pad_len = K//2
        
        ss = filt.size()
        
        
        pad_vector = (pad_len,pad_len,pad_len,pad_len)
        padded_x = F.pad(x, pad_vector)
        


        count = 0
        for i in range(0,K):
            for j in range(0,K):
                if i == 0 and j == 0 :
                    denoised = torch.mul(filt[:,count:count+1,:,:], padded_x[:,:,i:i+64,j:j+64])
                else:
                    denoised = denoised + torch.mul(filt[:,count:count+1,:,:], padded_x[:,:,i:i+64,j:j+64])
        
        
        return denoised
        
        
        
        
    
    #def _init_weights(m):
    
    def forward(self,x):
        enc1 = self.custom_block(self.conv_start, self.conv_64, x,self.batchnorm64)
        
        enc2 = self.avg_pool_downsample(enc1)
        enc2 = self.custom_block(self.conv_64to128, self.conv_128, enc2,self.batchnorm128)
        
        enc3 = self.avg_pool_downsample(enc2)
        enc3 = self.custom_block(self.conv_128to256, self.conv_256, enc3,self.batchnorm256)
        
        enc4 = self.avg_pool_downsample(enc3)
        enc4 = self.custom_block(self.conv_256to512, self.conv_512, enc4,self.batchnorm512)
        
        enc5 = self.avg_pool_downsample(enc4)
        enc5 = self.custom_block(self.conv_512, self.conv_512, enc5,self.batchnorm512)
        
    
        dec4 = self.upsample(enc5)
        dec4 = self.custom_block_res(self.conv_512, self.conv_512, dec4, enc4,self.batchnorm512)
        
        dec3 = self.upsample(dec4)
        dec3 = self.custom_block_res(self.conv_512to256, self.conv_256, dec3, enc3,self.batchnorm256)
        
        dec2 = self.upsample(dec3)
        dec2 = self.custom_block_res2(self.conv_256to128, self.conv_128toK2N, self.conv_K2N, dec2, enc2,self.batchnorm128,self.batchnormK2N)
        
        dec1 = self.upsample(dec2)
        
        output = self.convolve(dec1,x,self.K)

        return output

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    raise Exception("You requested GPU support, but there's no GPU on this machine")
    
net = KPN(device = device)
net = net.to(device)
summary(net,(1,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 64, 64]             640
#        BatchNorm2d-2           [-1, 64, 64, 64]             128
#             Conv2d-3           [-1, 64, 64, 64]          36,928
#        BatchNorm2d-4           [-1, 64, 64, 64]             128
#             Conv2d-5           [-1, 64, 64, 64]          36,928
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#          AvgPool2d-7           [-1, 64, 32, 32]               0
#             Conv2d-8          [-1, 128, 32, 32]          73,856
#        BatchNorm2d-9          [-1, 128, 32, 32]             256
#            Conv2d-10          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-11          [-1, 128, 32, 32]             256
#            Conv2d-12          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-13          [-1, 128, 32, 32]             256
#         AvgPool2d-14          [-1, 128, 16, 16]               0
#            Conv2d-15          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-16          [-1, 256, 16, 16]             512
#            Conv2d-17          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-18          [-1, 256, 16, 16]             512
#            Conv2d-19          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-20          [-1, 256, 16, 16]             512
#         AvgPool2d-21            [-1, 256, 8, 8]               0
#            Conv2d-22            [-1, 512, 8, 8]       1,180,160
#       BatchNorm2d-23            [-1, 512, 8, 8]           1,024
#            Conv2d-24            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-25            [-1, 512, 8, 8]           1,024
#            Conv2d-26            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-27            [-1, 512, 8, 8]           1,024
#         AvgPool2d-28            [-1, 512, 4, 4]               0
#            Conv2d-29            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-30            [-1, 512, 4, 4]           1,024
#            Conv2d-31            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-32            [-1, 512, 4, 4]           1,024
#            Conv2d-33            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-34            [-1, 512, 4, 4]           1,024
#          Upsample-35            [-1, 512, 8, 8]               0
#            Conv2d-36            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-37            [-1, 512, 8, 8]           1,024
#            Conv2d-38            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-39            [-1, 512, 8, 8]           1,024
#            Conv2d-40            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-41            [-1, 512, 8, 8]           1,024
#          Upsample-42          [-1, 512, 16, 16]               0
#            Conv2d-43          [-1, 256, 16, 16]       1,179,904
#       BatchNorm2d-44          [-1, 256, 16, 16]             512
#            Conv2d-45          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-46          [-1, 256, 16, 16]             512
#            Conv2d-47          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-48          [-1, 256, 16, 16]             512
#          Upsample-49          [-1, 256, 32, 32]               0
#            Conv2d-50          [-1, 128, 32, 32]         295,040
#       BatchNorm2d-51          [-1, 128, 32, 32]             256
#            Conv2d-52           [-1, 25, 32, 32]          28,825
#       BatchNorm2d-53           [-1, 25, 32, 32]              50
#            Conv2d-54           [-1, 25, 32, 32]           5,650
#       BatchNorm2d-55           [-1, 25, 32, 32]              50
#          Upsample-56           [-1, 25, 64, 64]               0
# ================================================================
# Total params: 24,680,847
# Trainable params: 24,680,847
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 35.12
# Params size (MB): 94.15
# Estimated Total Size (MB): 129.29
# ----------------------------------------------------------------

# %%
class Noisy_burst(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, root_dir, burst_len, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        
        f = []
        for (dirpath, dirnames, filenames) in walk(root_dir):
            f.extend(filenames)
            break
        
        #print(f)
        self.image_names = f
        self.burst_len = burst_len
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.image_names[idx])
        image = io.imread(img_name)
        image = rgb2gray(image)
        
        image = transform.resize(image, (80,80),anti_aliasing=True)
        
        sample_in = np.zeros((self.burst_len,64,64)).astype('float32')
        sample_out = np.zeros((self.burst_len,64,64)).astype('float32')
        
        for i in range(0,self.burst_len):
            x = np.random.randint(0,17)
            y = np.random.randint(0,17)
            x = 0
            y = 0
            sample_in[i,:,:] = image[x:x+64,y:y+64].astype('float32') + np.random.normal(0,0.05,(64,64)).astype('float32')
            sample_out[i,:,:] = image[x:x+64,y:y+64].astype('float32') + np.random.normal(0,0.05,(64,64)).astype('float32')
        
        
        
        sample_in[sample_in <0] = 0
        sample_in[sample_in >1] = 1
        
        sample_out[sample_out <0] = 0
        sample_out[sample_out >1] = 1
        sample_out = torch.from_numpy(sample_out)
        sample_in = torch.from_numpy(sample_in)
        #if self.transform:
        #    sample_in = self.transform(sample_in)
        #    sample_out = self.transform(sample_out)
        
        #print(sample_in.size())
        return sample_in,sample_out

# %%
data_transform = transforms.Compose([
        transforms.ToTensor(),
    ])

face_dataset = Noisy_burst(root_dir='../data/celebA/img_align_celeba', burst_len = 1, transform = data_transform)
dataloader = DataLoader(face_dataset, batch_size=32,
                        shuffle=True, num_workers=3)

# %%
a,b = face_dataset[0]
print(a.type())
# Out:
# torch.FloatTensor

# %%
num_epochs = 200
optimizer = optim.Adam(net.parameters(), lr=0.001)
criterion = nn.MSELoss()

# %%
running_loss = 0
count = 0
for epoch in range(num_epochs):
    for i, data in enumerate(dataloader, 0):
        net.zero_grad()
        inp,outp = data
        
        inp = inp.to(device)
        outp = outp.to(device)
        output = net(inp)
        
        error_mse = criterion(output, outp)
        optimizer.zero_grad()
        
        error_mse.backward()
        optimizer.step()
        
        running_loss += error_mse.item()
        count = count + 1
        
        if(count % 100 == 0):
            print('epoch : [%d,%d],loss: %.3f' %
              (epoch + 1, i,running_loss/100 ))
            running_loss = 0.0
            

    running_loss = 0.0
    if(epoch % 20 == 0):
        torch.save(net.state_dict(), 'Checkpoints/epoch_' + str(epoch) + '.pth')
# Out:
# epoch : [1,99],loss: 0.010
# epoch : [1,199],loss: 0.007
# epoch : [1,299],loss: 0.006
# epoch : [1,399],loss: 0.007
# epoch : [1,499],loss: 0.006
# epoch : [1,599],loss: 0.006
# epoch : [1,699],loss: 0.005
# epoch : [1,799],loss: 0.005
# epoch : [1,899],loss: 0.005
# epoch : [1,999],loss: 0.005
# epoch : [1,1099],loss: 0.005
# epoch : [1,1199],loss: 0.005
# epoch : [1,1299],loss: 0.005
# epoch : [1,1399],loss: 0.004
# epoch : [1,1499],loss: 0.004
# epoch : [1,1599],loss: 0.004
# epoch : [1,1699],loss: 0.004
# epoch : [1,1799],loss: 0.004
# epoch : [1,1899],loss: 0.004
# epoch : [1,1999],loss: 0.004
# epoch : [1,2099],loss: 0.004
# epoch : [1,2199],loss: 0.004
# epoch : [1,2299],loss: 0.004
# epoch : [1,2399],loss: 0.004
# epoch : [1,2499],loss: 0.004
# epoch : [1,2599],loss: 0.004
# epoch : [1,2699],loss: 0.004
# epoch : [1,2799],loss: 0.004
# epoch : [1,2899],loss: 0.004
# epoch : [1,2999],loss: 0.004
# epoch : [1,3099],loss: 0.004
# epoch : [1,3199],loss: 0.004
# epoch : [1,3299],loss: 0.004
# epoch : [1,3399],loss: 0.004
# epoch : [1,3499],loss: 0.004
# epoch : [1,3599],loss: 0.004
# epoch : [1,3699],loss: 0.004
# epoch : [1,3799],loss: 0.004
# epoch : [1,3899],loss: 0.004
# epoch : [1,3999],loss: 0.004
# epoch : [1,4099],loss: 0.004
# epoch : [1,4199],loss: 0.004
# epoch : [1,4299],loss: 0.004
# epoch : [1,4399],loss: 0.004
# epoch : [1,4499],loss: 0.004
# epoch : [1,4599],loss: 0.004
# epoch : [1,4699],loss: 0.004
# epoch : [1,4799],loss: 0.004
# epoch : [1,4899],loss: 0.004
# epoch : [1,4999],loss: 0.004
# epoch : [1,5099],loss: 0.004
# epoch : [1,5199],loss: 0.004
# epoch : [1,5299],loss: 0.004
# epoch : [1,5399],loss: 0.004
# epoch : [1,5499],loss: 0.004
# epoch : [1,5599],loss: 0.004
# epoch : [1,5699],loss: 0.004
# epoch : [1,5799],loss: 0.004
# epoch : [1,5899],loss: 0.004
# epoch : [1,5999],loss: 0.004
# epoch : [1,6099],loss: 0.004
# epoch : [1,6199],loss: 0.004
# epoch : [1,6299],loss: 0.004
# epoch : [2,67],loss: 0.003
# epoch : [2,167],loss: 0.004
# epoch : [2,267],loss: 0.004
# epoch : [2,367],loss: 0.004
# epoch : [2,467],loss: 0.004
# epoch : [2,567],loss: 0.004
# epoch : [2,667],loss: 0.004
# epoch : [2,767],loss: 0.004
# epoch : [2,867],loss: 0.004
# epoch : [2,967],loss: 0.004
# epoch : [2,1067],loss: 0.004
# epoch : [2,1167],loss: 0.004
# epoch : [2,1267],loss: 0.004
# epoch : [2,1367],loss: 0.004
# epoch : [2,1467],loss: 0.004
# epoch : [2,1567],loss: 0.004
# epoch : [2,1667],loss: 0.004
# epoch : [2,1767],loss: 0.004
# epoch : [2,1867],loss: 0.004
# epoch : [2,1967],loss: 0.004
# epoch : [2,2067],loss: 0.004
# epoch : [2,2167],loss: 0.004
# epoch : [2,2267],loss: 0.004
# epoch : [2,2367],loss: 0.004
# epoch : [2,2467],loss: 0.004
# epoch : [2,2567],loss: 0.004
# epoch : [2,2667],loss: 0.004
# epoch : [2,2767],loss: 0.004
# epoch : [2,2867],loss: 0.004
# epoch : [2,2967],loss: 0.004
# epoch : [2,3067],loss: 0.004
# epoch : [2,3167],loss: 0.004
# epoch : [2,3267],loss: 0.004
# epoch : [2,3367],loss: 0.004
# epoch : [2,3467],loss: 0.004
# epoch : [2,3567],loss: 0.004
# epoch : [2,3667],loss: 0.004
# epoch : [2,3767],loss: 0.004
# epoch : [2,3867],loss: 0.004
# epoch : [2,3967],loss: 0.004
# epoch : [2,4067],loss: 0.004
# epoch : [2,4167],loss: 0.004
# epoch : [2,4267],loss: 0.004
# epoch : [2,4367],loss: 0.004
# epoch : [2,4467],loss: 0.004
# epoch : [2,4567],loss: 0.004
# epoch : [2,4667],loss: 0.004
# epoch : [2,4767],loss: 0.004
# epoch : [2,4867],loss: 0.004
# epoch : [2,4967],loss: 0.004
# epoch : [2,5067],loss: 0.004
# epoch : [2,5167],loss: 0.004
# epoch : [2,5267],loss: 0.004
# epoch : [2,5367],loss: 0.004
# epoch : [2,5467],loss: 0.004
# epoch : [2,5567],loss: 0.004
# epoch : [2,5667],loss: 0.004
# epoch : [2,5767],loss: 0.004
# epoch : [2,5867],loss: 0.004
# epoch : [2,5967],loss: 0.004
# epoch : [2,6067],loss: 0.004
# epoch : [2,6167],loss: 0.004
# epoch : [2,6267],loss: 0.004
# epoch : [3,35],loss: 0.002
# epoch : [3,135],loss: 0.004
# epoch : [3,235],loss: 0.004
# epoch : [3,335],loss: 0.004
# epoch : [3,435],loss: 0.004
# epoch : [3,535],loss: 0.004
# epoch : [3,635],loss: 0.004
# epoch : [3,735],loss: 0.004
# epoch : [3,835],loss: 0.004
# epoch : [3,935],loss: 0.004
# epoch : [3,1035],loss: 0.004
# epoch : [3,1135],loss: 0.004
# epoch : [3,1235],loss: 0.004
# epoch : [3,1335],loss: 0.004
# epoch : [3,1435],loss: 0.004
# epoch : [3,1535],loss: 0.004
# epoch : [3,1635],loss: 0.004
# epoch : [3,1735],loss: 0.004
# epoch : [3,1835],loss: 0.004
# epoch : [3,1935],loss: 0.004
# epoch : [3,2035],loss: 0.004
# epoch : [3,2135],loss: 0.004
# epoch : [3,2235],loss: 0.004
# epoch : [3,2335],loss: 0.004
# epoch : [3,2435],loss: 0.004
# epoch : [3,2535],loss: 0.004
# epoch : [3,2635],loss: 0.004
# epoch : [3,2735],loss: 0.004
# epoch : [3,2835],loss: 0.004
# epoch : [3,2935],loss: 0.004
# epoch : [3,3035],loss: 0.004
# epoch : [3,3135],loss: 0.004
# epoch : [3,3235],loss: 0.004
# epoch : [3,3335],loss: 0.004
# epoch : [3,3435],loss: 0.004
# epoch : [3,3535],loss: 0.004
# epoch : [3,3635],loss: 0.004
# epoch : [3,3735],loss: 0.004
# epoch : [3,3835],loss: 0.004
# epoch : [3,3935],loss: 0.004
# epoch : [3,4035],loss: 0.004
# epoch : [3,4135],loss: 0.004
# epoch : [3,4235],loss: 0.004
# epoch : [3,4335],loss: 0.004
# epoch : [3,4435],loss: 0.004
# epoch : [3,4535],loss: 0.004
# epoch : [3,4635],loss: 0.004
# epoch : [3,4735],loss: 0.004
# epoch : [3,4835],loss: 0.004
# epoch : [3,4935],loss: 0.004
# epoch : [3,5035],loss: 0.004
# epoch : [3,5135],loss: 0.004
# epoch : [3,5235],loss: 0.004
# epoch : [3,5335],loss: 0.004
# epoch : [3,5435],loss: 0.004
# epoch : [3,5535],loss: 0.004
# epoch : [3,5635],loss: 0.004
# epoch : [3,5735],loss: 0.004
# epoch : [3,5835],loss: 0.004
# epoch : [3,5935],loss: 0.004
# epoch : [3,6035],loss: 0.004
# epoch : [3,6135],loss: 0.004
# epoch : [3,6235],loss: 0.004
# epoch : [4,3],loss: 0.000
# epoch : [4,103],loss: 0.004
# epoch : [4,203],loss: 0.004
# epoch : [4,303],loss: 0.004
# epoch : [4,403],loss: 0.004
# epoch : [4,503],loss: 0.004
# epoch : [4,603],loss: 0.004
# epoch : [4,703],loss: 0.004
# epoch : [4,803],loss: 0.004
# epoch : [4,903],loss: 0.004
# epoch : [4,1003],loss: 0.004
# epoch : [4,1103],loss: 0.004
# epoch : [4,1203],loss: 0.004
# epoch : [4,1303],loss: 0.004
# epoch : [4,1403],loss: 0.004
# epoch : [4,1503],loss: 0.004
# epoch : [4,1603],loss: 0.004
# epoch : [4,1703],loss: 0.004
# epoch : [4,1803],loss: 0.004
# epoch : [4,1903],loss: 0.004
# epoch : [4,2003],loss: 0.004
# epoch : [4,2103],loss: 0.004
# epoch : [4,2203],loss: 0.004
# epoch : [4,2303],loss: 0.004
# epoch : [4,2403],loss: 0.004
# epoch : [4,2503],loss: 0.004
# epoch : [4,2603],loss: 0.004
# epoch : [4,2703],loss: 0.004
# epoch : [4,2803],loss: 0.004
# epoch : [4,2903],loss: 0.004
# epoch : [4,3003],loss: 0.004
# epoch : [4,3103],loss: 0.004
# epoch : [4,3203],loss: 0.004
# epoch : [4,3303],loss: 0.004
# epoch : [4,3403],loss: 0.004
# epoch : [4,3503],loss: 0.004
# epoch : [4,3603],loss: 0.004
# epoch : [4,3703],loss: 0.004
# epoch : [4,3803],loss: 0.004
# epoch : [4,3903],loss: 0.004
# epoch : [4,4003],loss: 0.004
# epoch : [4,4103],loss: 0.004
# epoch : [4,4203],loss: 0.004
# epoch : [4,4303],loss: 0.004
# epoch : [4,4403],loss: 0.004
# epoch : [4,4503],loss: 0.004
# epoch : [4,4603],loss: 0.004
# epoch : [4,4703],loss: 0.004
# epoch : [4,4803],loss: 0.004
# epoch : [4,4903],loss: 0.004
# epoch : [4,5003],loss: 0.004
# epoch : [4,5103],loss: 0.004
# epoch : [4,5203],loss: 0.004
# epoch : [4,5303],loss: 0.004
# epoch : [4,5403],loss: 0.004
# epoch : [4,5503],loss: 0.004
# epoch : [4,5603],loss: 0.004
# epoch : [4,5703],loss: 0.004
# epoch : [4,5803],loss: 0.004
# epoch : [4,5903],loss: 0.004
# epoch : [4,6003],loss: 0.004
# epoch : [4,6103],loss: 0.004
# epoch : [4,6203],loss: 0.004
# epoch : [4,6303],loss: 0.004
# epoch : [5,71],loss: 0.003
# epoch : [5,171],loss: 0.004
# epoch : [5,271],loss: 0.004
# epoch : [5,371],loss: 0.004
# epoch : [5,471],loss: 0.004
# epoch : [5,571],loss: 0.004
# epoch : [5,671],loss: 0.004
# epoch : [5,771],loss: 0.004
# epoch : [5,871],loss: 0.004
# epoch : [5,971],loss: 0.004
# epoch : [5,1071],loss: 0.004
# epoch : [5,1171],loss: 0.004
# epoch : [5,1271],loss: 0.004
# epoch : [5,1371],loss: 0.004
# epoch : [5,1471],loss: 0.004
# epoch : [5,1571],loss: 0.004
# epoch : [5,1671],loss: 0.004
# epoch : [5,1771],loss: 0.004
# epoch : [5,1871],loss: 0.004
# epoch : [5,1971],loss: 0.004
# epoch : [5,2071],loss: 0.004
# epoch : [5,2171],loss: 0.004
# epoch : [5,2271],loss: 0.004
# epoch : [5,2371],loss: 0.004
# epoch : [5,2471],loss: 0.004
# epoch : [5,2571],loss: 0.004
# epoch : [5,2671],loss: 0.004
# epoch : [5,2771],loss: 0.004
# epoch : [5,2871],loss: 0.004
# epoch : [5,2971],loss: 0.004
# epoch : [5,3071],loss: 0.004
# epoch : [5,3171],loss: 0.004
# epoch : [5,3271],loss: 0.004
# epoch : [5,3371],loss: 0.004
# epoch : [5,3471],loss: 0.004
# epoch : [5,3571],loss: 0.004
# epoch : [5,3671],loss: 0.004
# epoch : [5,3771],loss: 0.004
# epoch : [5,3871],loss: 0.004
# epoch : [5,3971],loss: 0.004
# epoch : [5,4071],loss: 0.004
# epoch : [5,4171],loss: 0.004
# epoch : [5,4271],loss: 0.004
# epoch : [5,4371],loss: 0.004
# epoch : [5,4471],loss: 0.004
# epoch : [5,4571],loss: 0.004
# epoch : [5,4671],loss: 0.004
# epoch : [5,4771],loss: 0.004
# epoch : [5,4871],loss: 0.004
# epoch : [5,4971],loss: 0.004
# epoch : [5,5071],loss: 0.004
# epoch : [5,5171],loss: 0.004
# epoch : [5,5271],loss: 0.004
# epoch : [5,5371],loss: 0.004
# epoch : [5,5471],loss: 0.004
# epoch : [5,5571],loss: 0.004
# epoch : [5,5671],loss: 0.004
# epoch : [5,5771],loss: 0.004
# epoch : [5,5871],loss: 0.004
# epoch : [5,5971],loss: 0.004
# epoch : [5,6071],loss: 0.004
# epoch : [5,6171],loss: 0.004
# epoch : [5,6271],loss: 0.004
# epoch : [6,39],loss: 0.002
# epoch : [6,139],loss: 0.004
# epoch : [6,239],loss: 0.004
# epoch : [6,339],loss: 0.004
# epoch : [6,439],loss: 0.004
# epoch : [6,539],loss: 0.004
# epoch : [6,639],loss: 0.004
# epoch : [6,739],loss: 0.004
# epoch : [6,839],loss: 0.004
# epoch : [6,939],loss: 0.004
# epoch : [6,1039],loss: 0.004
# epoch : [6,1139],loss: 0.004
# epoch : [6,1239],loss: 0.004
# epoch : [6,1339],loss: 0.004
# epoch : [6,1439],loss: 0.004
# epoch : [6,1539],loss: 0.004
# epoch : [6,1639],loss: 0.004
# epoch : [6,1739],loss: 0.004
# epoch : [6,1839],loss: 0.004
# epoch : [6,1939],loss: 0.004
# epoch : [6,2039],loss: 0.004
# epoch : [6,2139],loss: 0.004
# epoch : [6,2239],loss: 0.004
# epoch : [6,2339],loss: 0.004
# epoch : [6,2439],loss: 0.004
# epoch : [6,2539],loss: 0.004
# epoch : [6,2639],loss: 0.004
# epoch : [6,2739],loss: 0.004
# epoch : [6,2839],loss: 0.004
# epoch : [6,2939],loss: 0.004
# epoch : [6,3039],loss: 0.004
# epoch : [6,3139],loss: 0.004
# epoch : [6,3239],loss: 0.004
# epoch : [6,3339],loss: 0.004
# epoch : [6,3439],loss: 0.004
# epoch : [6,3539],loss: 0.004
# epoch : [6,3639],loss: 0.004
# epoch : [6,3739],loss: 0.004
# epoch : [6,3839],loss: 0.004
# epoch : [6,3939],loss: 0.004
# epoch : [6,4039],loss: 0.004
# epoch : [6,4139],loss: 0.004
# epoch : [6,4239],loss: 0.004
# epoch : [6,4339],loss: 0.004
# epoch : [6,4439],loss: 0.004
# epoch : [6,4539],loss: 0.004
# epoch : [6,4639],loss: 0.004
# epoch : [6,4739],loss: 0.004
# epoch : [6,4839],loss: 0.004
# epoch : [6,4939],loss: 0.004
# epoch : [6,5039],loss: 0.004
# epoch : [6,5139],loss: 0.004
# epoch : [6,5239],loss: 0.004
# epoch : [6,5339],loss: 0.004
# epoch : [6,5439],loss: 0.004
# epoch : [6,5539],loss: 0.004
# epoch : [6,5639],loss: 0.004
# epoch : [6,5739],loss: 0.004
# epoch : [6,5839],loss: 0.004
# epoch : [6,5939],loss: 0.004
# epoch : [6,6039],loss: 0.004
# epoch : [6,6139],loss: 0.004
# epoch : [6,6239],loss: 0.004
# epoch : [7,7],loss: 0.000
# epoch : [7,107],loss: 0.004
# epoch : [7,207],loss: 0.004
# epoch : [7,307],loss: 0.004
# epoch : [7,407],loss: 0.004
# epoch : [7,507],loss: 0.004
# epoch : [7,607],loss: 0.004
# epoch : [7,707],loss: 0.004
# epoch : [7,807],loss: 0.004
# epoch : [7,907],loss: 0.004
# epoch : [7,1007],loss: 0.004
# epoch : [7,1107],loss: 0.004
# epoch : [7,1207],loss: 0.004
# epoch : [7,1307],loss: 0.004
# epoch : [7,1407],loss: 0.004
# epoch : [7,1507],loss: 0.004
# epoch : [7,1607],loss: 0.004
# epoch : [7,1707],loss: 0.004
# epoch : [7,1807],loss: 0.004
# epoch : [7,1907],loss: 0.004
# epoch : [7,2007],loss: 0.004
# epoch : [7,2107],loss: 0.004
# epoch : [7,2207],loss: 0.004
# epoch : [7,2307],loss: 0.004
# epoch : [7,2407],loss: 0.004
# epoch : [7,2507],loss: 0.004
# epoch : [7,2607],loss: 0.004
# epoch : [7,2707],loss: 0.004
# epoch : [7,2807],loss: 0.004
# epoch : [7,2907],loss: 0.004
# epoch : [7,3007],loss: 0.004
# epoch : [7,3107],loss: 0.004
# epoch : [7,3207],loss: 0.004
# epoch : [7,3307],loss: 0.004
# epoch : [7,3407],loss: 0.004
# epoch : [7,3507],loss: 0.004
# epoch : [7,3607],loss: 0.004
# epoch : [7,3707],loss: 0.004
# epoch : [7,3807],loss: 0.004
# epoch : [7,3907],loss: 0.004
# epoch : [7,4007],loss: 0.004
# epoch : [7,4107],loss: 0.004
# epoch : [7,4207],loss: 0.004
# epoch : [7,4307],loss: 0.004
# epoch : [7,4407],loss: 0.004
# epoch : [7,4507],loss: 0.004
# epoch : [7,4607],loss: 0.004
# epoch : [7,4707],loss: 0.004
# epoch : [7,4807],loss: 0.004
# epoch : [7,4907],loss: 0.004
# epoch : [7,5007],loss: 0.004
# epoch : [7,5107],loss: 0.004
# epoch : [7,5207],loss: 0.004
# epoch : [7,5307],loss: 0.004
# epoch : [7,5407],loss: 0.004
# epoch : [7,5507],loss: 0.004
# epoch : [7,5607],loss: 0.004
# epoch : [7,5707],loss: 0.004
# epoch : [7,5807],loss: 0.004
# epoch : [7,5907],loss: 0.004
# epoch : [7,6007],loss: 0.004
# epoch : [7,6107],loss: 0.004
# epoch : [7,6207],loss: 0.004
# epoch : [7,6307],loss: 0.004
# epoch : [8,75],loss: 0.003
# epoch : [8,175],loss: 0.004
# epoch : [8,275],loss: 0.004
# epoch : [8,375],loss: 0.004
# epoch : [8,475],loss: 0.004
# epoch : [8,575],loss: 0.004
# epoch : [8,675],loss: 0.004
# epoch : [8,775],loss: 0.004
# epoch : [8,875],loss: 0.004
# epoch : [8,975],loss: 0.004
# epoch : [8,1075],loss: 0.004
# epoch : [8,1175],loss: 0.004
# epoch : [8,1275],loss: 0.004
# epoch : [8,1375],loss: 0.004
# epoch : [8,1475],loss: 0.004
# epoch : [8,1575],loss: 0.004
# epoch : [8,1675],loss: 0.004
# epoch : [8,1775],loss: 0.004
# epoch : [8,1875],loss: 0.004
# epoch : [8,1975],loss: 0.004
# epoch : [8,2075],loss: 0.004
# epoch : [8,2175],loss: 0.004
# epoch : [8,2275],loss: 0.004
# epoch : [8,2375],loss: 0.004
# epoch : [8,2475],loss: 0.004
# epoch : [8,2575],loss: 0.004
# epoch : [8,2675],loss: 0.004
# epoch : [8,2775],loss: 0.004
# epoch : [8,2875],loss: 0.004
# epoch : [8,2975],loss: 0.004
# epoch : [8,3075],loss: 0.004
# epoch : [8,3175],loss: 0.004
# epoch : [8,3275],loss: 0.004
# epoch : [8,3375],loss: 0.004
# epoch : [8,3475],loss: 0.004
# epoch : [8,3575],loss: 0.004
# epoch : [8,3675],loss: 0.004
# epoch : [8,3775],loss: 0.004
# epoch : [8,3875],loss: 0.004
# epoch : [8,3975],loss: 0.004
# epoch : [8,4075],loss: 0.004
# epoch : [8,4175],loss: 0.004
# epoch : [8,4275],loss: 0.004
# epoch : [8,4375],loss: 0.004
# epoch : [8,4475],loss: 0.004
# epoch : [8,4575],loss: 0.004
# epoch : [8,4675],loss: 0.004
# epoch : [8,4775],loss: 0.004
# epoch : [8,4875],loss: 0.004
# epoch : [8,4975],loss: 0.004
# epoch : [8,5075],loss: 0.004
# epoch : [8,5175],loss: 0.004
# epoch : [8,5275],loss: 0.004
# epoch : [8,5375],loss: 0.004
# epoch : [8,5475],loss: 0.004
# epoch : [8,5575],loss: 0.004
# epoch : [8,5675],loss: 0.004
# epoch : [8,5775],loss: 0.004
# epoch : [8,5875],loss: 0.004
# epoch : [8,5975],loss: 0.004
# epoch : [8,6075],loss: 0.004
# epoch : [8,6175],loss: 0.004
# epoch : [8,6275],loss: 0.004
# epoch : [9,43],loss: 0.002
# epoch : [9,143],loss: 0.004
# epoch : [9,243],loss: 0.004
# epoch : [9,343],loss: 0.004
# epoch : [9,443],loss: 0.004
# epoch : [9,543],loss: 0.004
# epoch : [9,643],loss: 0.004
# epoch : [9,743],loss: 0.004
# epoch : [9,843],loss: 0.004
# epoch : [9,943],loss: 0.004
# epoch : [9,1043],loss: 0.004
# epoch : [9,1143],loss: 0.004
# epoch : [9,1243],loss: 0.004
# epoch : [9,1343],loss: 0.004
# epoch : [9,1443],loss: 0.004
# epoch : [9,1543],loss: 0.004
# epoch : [9,1643],loss: 0.004
# epoch : [9,1743],loss: 0.004
# epoch : [9,1843],loss: 0.004
# epoch : [9,1943],loss: 0.004
# epoch : [9,2043],loss: 0.004
# epoch : [9,2143],loss: 0.004
# epoch : [9,2243],loss: 0.004
# epoch : [9,2343],loss: 0.004
# epoch : [9,2443],loss: 0.004
# epoch : [9,2543],loss: 0.004
# epoch : [9,2643],loss: 0.004
# epoch : [9,2743],loss: 0.004
# epoch : [9,2843],loss: 0.004
# epoch : [9,2943],loss: 0.004
# epoch : [9,3043],loss: 0.004
# epoch : [9,3143],loss: 0.004
# epoch : [9,3243],loss: 0.004
# epoch : [9,3343],loss: 0.004
# epoch : [9,3443],loss: 0.004
# epoch : [9,3543],loss: 0.004
# epoch : [9,3643],loss: 0.004
# epoch : [9,3743],loss: 0.004
# epoch : [9,3843],loss: 0.004
# epoch : [9,3943],loss: 0.004
# epoch : [9,4043],loss: 0.004
# epoch : [9,4143],loss: 0.004
# epoch : [9,4243],loss: 0.004
# epoch : [9,4343],loss: 0.004
# epoch : [9,4443],loss: 0.004
# epoch : [9,4543],loss: 0.004
# epoch : [9,4643],loss: 0.004
# epoch : [9,4743],loss: 0.004
# epoch : [9,4843],loss: 0.004
# epoch : [9,4943],loss: 0.004
# epoch : [9,5043],loss: 0.004
# epoch : [9,5143],loss: 0.004
# epoch : [9,5243],loss: 0.004
# epoch : [9,5343],loss: 0.004
# epoch : [9,5443],loss: 0.004
# epoch : [9,5543],loss: 0.004
# epoch : [9,5643],loss: 0.004
# epoch : [9,5743],loss: 0.004
# epoch : [9,5843],loss: 0.004
# epoch : [9,5943],loss: 0.004
# epoch : [9,6043],loss: 0.004
# epoch : [9,6143],loss: 0.004
# epoch : [9,6243],loss: 0.004
# epoch : [10,11],loss: 0.000
# epoch : [10,111],loss: 0.004
# epoch : [10,211],loss: 0.004
# epoch : [10,311],loss: 0.004
# epoch : [10,411],loss: 0.004
# epoch : [10,511],loss: 0.004
# epoch : [10,611],loss: 0.004
# epoch : [10,711],loss: 0.004
# epoch : [10,811],loss: 0.004
# epoch : [10,911],loss: 0.004
# epoch : [10,1011],loss: 0.004
# epoch : [10,1111],loss: 0.004
# epoch : [10,1211],loss: 0.004
# epoch : [10,1311],loss: 0.004
# epoch : [10,1411],loss: 0.004
# epoch : [10,1511],loss: 0.004
# epoch : [10,1611],loss: 0.004
# epoch : [10,1711],loss: 0.004
# epoch : [10,1811],loss: 0.004
# epoch : [10,1911],loss: 0.004
# epoch : [10,2011],loss: 0.004
# epoch : [10,2111],loss: 0.004
# epoch : [10,2211],loss: 0.004
# epoch : [10,2311],loss: 0.004
# epoch : [10,2411],loss: 0.004
# epoch : [10,2511],loss: 0.004
# epoch : [10,2611],loss: 0.004
# epoch : [10,2711],loss: 0.004
# epoch : [10,2811],loss: 0.004
# epoch : [10,2911],loss: 0.004
# epoch : [10,3011],loss: 0.004
# epoch : [10,3111],loss: 0.004
# epoch : [10,3211],loss: 0.004
# epoch : [10,3311],loss: 0.004
# epoch : [10,3411],loss: 0.004
# epoch : [10,3511],loss: 0.004
# epoch : [10,3611],loss: 0.004
# epoch : [10,3711],loss: 0.004
# epoch : [10,3811],loss: 0.004
# epoch : [10,3911],loss: 0.004
# epoch : [10,4011],loss: 0.004
# epoch : [10,4111],loss: 0.004
# epoch : [10,4211],loss: 0.004
# epoch : [10,4311],loss: 0.004
# epoch : [10,4411],loss: 0.004
# epoch : [10,4511],loss: 0.004
# epoch : [10,4611],loss: 0.004
# epoch : [10,4711],loss: 0.004
# epoch : [10,4811],loss: 0.004
# epoch : [10,4911],loss: 0.004
# epoch : [10,5011],loss: 0.004
# epoch : [10,5111],loss: 0.004
# epoch : [10,5211],loss: 0.004
# epoch : [10,5311],loss: 0.004
# epoch : [10,5411],loss: 0.004
# epoch : [10,5511],loss: 0.004
# epoch : [10,5611],loss: 0.004
# epoch : [10,5711],loss: 0.004
# epoch : [10,5811],loss: 0.004
# epoch : [10,5911],loss: 0.004
# epoch : [10,6011],loss: 0.004
# epoch : [10,6111],loss: 0.004
# epoch : [10,6211],loss: 0.004
# epoch : [10,6311],loss: 0.004
# epoch : [11,79],loss: 0.003
# epoch : [11,179],loss: 0.004
# epoch : [11,279],loss: 0.004
# epoch : [11,379],loss: 0.004
# epoch : [11,479],loss: 0.004
# epoch : [11,579],loss: 0.004
# epoch : [11,679],loss: 0.004
# epoch : [11,779],loss: 0.004
# epoch : [11,879],loss: 0.004
# epoch : [11,979],loss: 0.004
# epoch : [11,1079],loss: 0.004
# epoch : [11,1179],loss: 0.004
# epoch : [11,1279],loss: 0.004
# epoch : [11,1379],loss: 0.004
# epoch : [11,1479],loss: 0.004
# epoch : [11,1579],loss: 0.004
# epoch : [11,1679],loss: 0.004
# epoch : [11,1779],loss: 0.004
# epoch : [11,1879],loss: 0.004
# epoch : [11,1979],loss: 0.004
# epoch : [11,2079],loss: 0.004
# epoch : [11,2179],loss: 0.004
# epoch : [11,2279],loss: 0.004
# epoch : [11,2379],loss: 0.004
# epoch : [11,2479],loss: 0.004
# epoch : [11,2579],loss: 0.004
# epoch : [11,2679],loss: 0.004
# epoch : [11,2779],loss: 0.004
# epoch : [11,2879],loss: 0.004
# epoch : [11,2979],loss: 0.004
# epoch : [11,3079],loss: 0.004
# epoch : [11,3179],loss: 0.004
# epoch : [11,3279],loss: 0.004
# epoch : [11,3379],loss: 0.004
# epoch : [11,3479],loss: 0.004
# epoch : [11,3579],loss: 0.004
# epoch : [11,3679],loss: 0.004
# epoch : [11,3779],loss: 0.004
# epoch : [11,3879],loss: 0.004
# epoch : [11,3979],loss: 0.004
# epoch : [11,4079],loss: 0.004
# epoch : [11,4179],loss: 0.004
# epoch : [11,4279],loss: 0.004
# epoch : [11,4379],loss: 0.004
# epoch : [11,4479],loss: 0.004
# epoch : [11,4579],loss: 0.004
# epoch : [11,4679],loss: 0.004
# epoch : [11,4779],loss: 0.004
# epoch : [11,4879],loss: 0.004
# epoch : [11,4979],loss: 0.004
# epoch : [11,5079],loss: 0.004
# epoch : [11,5179],loss: 0.004
# epoch : [11,5279],loss: 0.004
# epoch : [11,5379],loss: 0.004
# epoch : [11,5479],loss: 0.004
# epoch : [11,5579],loss: 0.004
# epoch : [11,5679],loss: 0.004
# epoch : [11,5779],loss: 0.004
# epoch : [11,5879],loss: 0.004
# epoch : [11,5979],loss: 0.004
# epoch : [11,6079],loss: 0.004
# epoch : [11,6179],loss: 0.004
# epoch : [11,6279],loss: 0.004
# epoch : [12,47],loss: 0.002
# epoch : [12,147],loss: 0.004
# epoch : [12,247],loss: 0.004
# epoch : [12,347],loss: 0.004
# epoch : [12,447],loss: 0.004
# epoch : [12,547],loss: 0.004
# epoch : [12,647],loss: 0.004
# epoch : [12,747],loss: 0.004
# epoch : [12,847],loss: 0.004
# epoch : [12,947],loss: 0.004
# epoch : [12,1047],loss: 0.004
# epoch : [12,1147],loss: 0.004
# epoch : [12,1247],loss: 0.004
# epoch : [12,1347],loss: 0.004
# epoch : [12,1447],loss: 0.004
# epoch : [12,1547],loss: 0.004
# epoch : [12,1647],loss: 0.004
# epoch : [12,1747],loss: 0.004
# epoch : [12,1847],loss: 0.004
# epoch : [12,1947],loss: 0.004
# epoch : [12,2047],loss: 0.004
# epoch : [12,2147],loss: 0.004
# epoch : [12,2247],loss: 0.004
# epoch : [12,2347],loss: 0.004
# epoch : [12,2447],loss: 0.004
# epoch : [12,2547],loss: 0.004
# epoch : [12,2647],loss: 0.004
# epoch : [12,2747],loss: 0.004
# epoch : [12,2847],loss: 0.004
# epoch : [12,2947],loss: 0.004
# epoch : [12,3047],loss: 0.004
# epoch : [12,3147],loss: 0.004
# epoch : [12,3247],loss: 0.004
# epoch : [12,3347],loss: 0.004
# epoch : [12,3447],loss: 0.004
# epoch : [12,3547],loss: 0.004
# epoch : [12,3647],loss: 0.004
# epoch : [12,3747],loss: 0.004
# epoch : [12,3847],loss: 0.004
# epoch : [12,3947],loss: 0.004
# epoch : [12,4047],loss: 0.004
# epoch : [12,4147],loss: 0.004
# epoch : [12,4247],loss: 0.004
# epoch : [12,4347],loss: 0.004
# epoch : [12,4447],loss: 0.004
# epoch : [12,4547],loss: 0.004
# epoch : [12,4647],loss: 0.004
# epoch : [12,4747],loss: 0.004
# epoch : [12,4847],loss: 0.004
# epoch : [12,4947],loss: 0.004
# epoch : [12,5047],loss: 0.004
# epoch : [12,5147],loss: 0.004
# epoch : [12,5247],loss: 0.004
# epoch : [12,5347],loss: 0.004
# epoch : [12,5447],loss: 0.004
# epoch : [12,5547],loss: 0.004
# epoch : [12,5647],loss: 0.004
# epoch : [12,5747],loss: 0.004
# epoch : [12,5847],loss: 0.004
# epoch : [12,5947],loss: 0.004
# epoch : [12,6047],loss: 0.004
# epoch : [12,6147],loss: 0.004
# epoch : [12,6247],loss: 0.004
# epoch : [13,15],loss: 0.001
# epoch : [13,115],loss: 0.004
# epoch : [13,215],loss: 0.004
# epoch : [13,315],loss: 0.004
# epoch : [13,415],loss: 0.004
# epoch : [13,515],loss: 0.004
# epoch : [13,615],loss: 0.004
# epoch : [13,715],loss: 0.004
# epoch : [13,815],loss: 0.004
# epoch : [13,915],loss: 0.004
# epoch : [13,1015],loss: 0.004
# epoch : [13,1115],loss: 0.004
# epoch : [13,1215],loss: 0.004
# epoch : [13,1315],loss: 0.004
# epoch : [13,1415],loss: 0.004
# epoch : [13,1515],loss: 0.004
# epoch : [13,1615],loss: 0.004
# epoch : [13,1715],loss: 0.004
# epoch : [13,1815],loss: 0.004
# epoch : [13,1915],loss: 0.004
# epoch : [13,2015],loss: 0.004
# epoch : [13,2115],loss: 0.004
# epoch : [13,2215],loss: 0.004
# epoch : [13,2315],loss: 0.004
# epoch : [13,2415],loss: 0.004
# epoch : [13,2515],loss: 0.004
# epoch : [13,2615],loss: 0.004
# epoch : [13,2715],loss: 0.004
# epoch : [13,2815],loss: 0.004
# epoch : [13,2915],loss: 0.004
# epoch : [13,3015],loss: 0.004
# epoch : [13,3115],loss: 0.004
# epoch : [13,3215],loss: 0.004
# epoch : [13,3315],loss: 0.004
# epoch : [13,3415],loss: 0.004
# epoch : [13,3515],loss: 0.004
# epoch : [13,3615],loss: 0.004
# epoch : [13,3715],loss: 0.004
# epoch : [13,3815],loss: 0.004
# epoch : [13,3915],loss: 0.004
# epoch : [13,4015],loss: 0.004
# epoch : [13,4115],loss: 0.004
# epoch : [13,4215],loss: 0.004
# epoch : [13,4315],loss: 0.004
# epoch : [13,4415],loss: 0.004
# epoch : [13,4515],loss: 0.004
# epoch : [13,4615],loss: 0.004
# epoch : [13,4715],loss: 0.004
# epoch : [13,4815],loss: 0.004
# epoch : [13,4915],loss: 0.004
# epoch : [13,5015],loss: 0.004
# epoch : [13,5115],loss: 0.004
# epoch : [13,5215],loss: 0.004
# epoch : [13,5315],loss: 0.004
# epoch : [13,5415],loss: 0.004
# epoch : [13,5515],loss: 0.004
# epoch : [13,5615],loss: 0.004
# epoch : [13,5715],loss: 0.004
# epoch : [13,5815],loss: 0.004
# epoch : [13,5915],loss: 0.004
# epoch : [13,6015],loss: 0.004
# epoch : [13,6115],loss: 0.004
# epoch : [13,6215],loss: 0.004
# epoch : [13,6315],loss: 0.004
# epoch : [14,83],loss: 0.003
# epoch : [14,183],loss: 0.004
# epoch : [14,283],loss: 0.004
# epoch : [14,383],loss: 0.004
# epoch : [14,483],loss: 0.004
# epoch : [14,583],loss: 0.004
# epoch : [14,683],loss: 0.004
# epoch : [14,783],loss: 0.004
# epoch : [14,883],loss: 0.004
# epoch : [14,983],loss: 0.004
# epoch : [14,1083],loss: 0.004
# epoch : [14,1183],loss: 0.004
# epoch : [14,1283],loss: 0.004
# epoch : [14,1383],loss: 0.004
# epoch : [14,1483],loss: 0.004
# epoch : [14,1583],loss: 0.004
# epoch : [14,1683],loss: 0.004
# epoch : [14,1783],loss: 0.004
# epoch : [14,1883],loss: 0.004
# epoch : [14,1983],loss: 0.004
# epoch : [14,2083],loss: 0.004
# epoch : [14,2183],loss: 0.004
# epoch : [14,2283],loss: 0.004
# epoch : [14,2383],loss: 0.004
# epoch : [14,2483],loss: 0.004
# epoch : [14,2583],loss: 0.004
# epoch : [14,2683],loss: 0.004
# epoch : [14,2783],loss: 0.004
# epoch : [14,2883],loss: 0.004
# epoch : [14,2983],loss: 0.004
# epoch : [14,3083],loss: 0.004
# epoch : [14,3183],loss: 0.004
# epoch : [14,3283],loss: 0.004
# epoch : [14,3383],loss: 0.004
# epoch : [14,3483],loss: 0.004
# epoch : [14,3583],loss: 0.004
# epoch : [14,3683],loss: 0.004
# epoch : [14,3783],loss: 0.004
# epoch : [14,3883],loss: 0.004
# epoch : [14,3983],loss: 0.004
# epoch : [14,4083],loss: 0.004
# epoch : [14,4183],loss: 0.004
# epoch : [14,4283],loss: 0.004
# epoch : [14,4383],loss: 0.004
# epoch : [14,4483],loss: 0.004
# epoch : [14,4583],loss: 0.004
# epoch : [14,4683],loss: 0.004
# epoch : [14,4783],loss: 0.004
# epoch : [14,4883],loss: 0.004
# epoch : [14,4983],loss: 0.004
# epoch : [14,5083],loss: 0.004
# epoch : [14,5183],loss: 0.004
# epoch : [14,5283],loss: 0.004
# epoch : [14,5383],loss: 0.004
# epoch : [14,5483],loss: 0.004
# epoch : [14,5583],loss: 0.004
# epoch : [14,5683],loss: 0.004
# epoch : [14,5783],loss: 0.004
# epoch : [14,5883],loss: 0.004
# epoch : [14,5983],loss: 0.004
# epoch : [14,6083],loss: 0.004
# epoch : [14,6183],loss: 0.004
# epoch : [14,6283],loss: 0.004
# epoch : [15,51],loss: 0.002
# epoch : [15,151],loss: 0.004
# epoch : [15,251],loss: 0.004
# epoch : [15,351],loss: 0.004
# epoch : [15,451],loss: 0.004
# epoch : [15,551],loss: 0.004
# epoch : [15,651],loss: 0.004
# epoch : [15,751],loss: 0.004
# epoch : [15,851],loss: 0.004
# epoch : [15,951],loss: 0.004
# epoch : [15,1051],loss: 0.004
# epoch : [15,1151],loss: 0.004
# epoch : [15,1251],loss: 0.004
# epoch : [15,1351],loss: 0.004
# epoch : [15,1451],loss: 0.004
# epoch : [15,1551],loss: 0.004
# epoch : [15,1651],loss: 0.004
# epoch : [15,1751],loss: 0.004
# epoch : [15,1851],loss: 0.004
# epoch : [15,1951],loss: 0.004
# epoch : [15,2051],loss: 0.004
# epoch : [15,2151],loss: 0.004
# epoch : [15,2251],loss: 0.004
# epoch : [15,2351],loss: 0.004
# epoch : [15,2451],loss: 0.004
# epoch : [15,2551],loss: 0.004
# epoch : [15,2651],loss: 0.004
# epoch : [15,2751],loss: 0.004
# epoch : [15,2851],loss: 0.004
# epoch : [15,2951],loss: 0.004
# epoch : [15,3051],loss: 0.004
# epoch : [15,3151],loss: 0.004
# epoch : [15,3251],loss: 0.004
# epoch : [15,3351],loss: 0.004
# epoch : [15,3451],loss: 0.004
# epoch : [15,3551],loss: 0.004
# epoch : [15,3651],loss: 0.004
# epoch : [15,3751],loss: 0.004
# epoch : [15,3851],loss: 0.004
# epoch : [15,3951],loss: 0.004
# epoch : [15,4051],loss: 0.004
# epoch : [15,4151],loss: 0.004
# epoch : [15,4251],loss: 0.004
# epoch : [15,4351],loss: 0.004
# epoch : [15,4451],loss: 0.004
# epoch : [15,4551],loss: 0.004
# epoch : [15,4651],loss: 0.004
# epoch : [15,4751],loss: 0.004
# epoch : [15,4851],loss: 0.004
# epoch : [15,4951],loss: 0.004
# epoch : [15,5051],loss: 0.004
# epoch : [15,5151],loss: 0.004
# epoch : [15,5251],loss: 0.004
# epoch : [15,5351],loss: 0.004
# epoch : [15,5451],loss: 0.004
# epoch : [15,5551],loss: 0.004
# epoch : [15,5651],loss: 0.004
# epoch : [15,5751],loss: 0.004
# epoch : [15,5851],loss: 0.004
# epoch : [15,5951],loss: 0.004
# epoch : [15,6051],loss: 0.004
# epoch : [15,6151],loss: 0.004
# epoch : [15,6251],loss: 0.004
# epoch : [16,19],loss: 0.001
# epoch : [16,119],loss: 0.004
# epoch : [16,219],loss: 0.004
# epoch : [16,319],loss: 0.004
# epoch : [16,419],loss: 0.004
# epoch : [16,519],loss: 0.004
# epoch : [16,619],loss: 0.004
# epoch : [16,719],loss: 0.004
# epoch : [16,819],loss: 0.004
# epoch : [16,919],loss: 0.004
# epoch : [16,1019],loss: 0.004
# epoch : [16,1119],loss: 0.004
# epoch : [16,1219],loss: 0.004
# epoch : [16,1319],loss: 0.004
# epoch : [16,1419],loss: 0.004
# epoch : [16,1519],loss: 0.004
# epoch : [16,1619],loss: 0.004
# epoch : [16,1719],loss: 0.004
# epoch : [16,1819],loss: 0.004
# epoch : [16,1919],loss: 0.004
# epoch : [16,2019],loss: 0.004
# epoch : [16,2119],loss: 0.004
# epoch : [16,2219],loss: 0.004
# epoch : [16,2319],loss: 0.004
# epoch : [16,2419],loss: 0.004
# epoch : [16,2519],loss: 0.004
# epoch : [16,2619],loss: 0.004
# epoch : [16,2719],loss: 0.004
# epoch : [16,2819],loss: 0.004
# epoch : [16,2919],loss: 0.004
# epoch : [16,3019],loss: 0.004
# epoch : [16,3119],loss: 0.004
# epoch : [16,3219],loss: 0.004
# epoch : [16,3319],loss: 0.004
# epoch : [16,3419],loss: 0.004
# epoch : [16,3519],loss: 0.004
# epoch : [16,3619],loss: 0.004
# epoch : [16,3719],loss: 0.004
# epoch : [16,3819],loss: 0.004
# epoch : [16,3919],loss: 0.004
# epoch : [16,4019],loss: 0.004
# epoch : [16,4119],loss: 0.004
# epoch : [16,4219],loss: 0.004
# epoch : [16,4319],loss: 0.004
# epoch : [16,4419],loss: 0.004
# epoch : [16,4519],loss: 0.004
# epoch : [16,4619],loss: 0.004
# epoch : [16,4719],loss: 0.004
# epoch : [16,4819],loss: 0.004
# epoch : [16,4919],loss: 0.004
# epoch : [16,5019],loss: 0.004
# epoch : [16,5119],loss: 0.004
# epoch : [16,5219],loss: 0.004
# epoch : [16,5319],loss: 0.004
# epoch : [16,5419],loss: 0.004
# epoch : [16,5519],loss: 0.004
# epoch : [16,5619],loss: 0.004
# epoch : [16,5719],loss: 0.004
# epoch : [16,5819],loss: 0.004
# epoch : [16,5919],loss: 0.004
# epoch : [16,6019],loss: 0.004
# epoch : [16,6119],loss: 0.004
# epoch : [16,6219],loss: 0.004
# epoch : [16,6319],loss: 0.004
# epoch : [17,87],loss: 0.004
# epoch : [17,187],loss: 0.004
# epoch : [17,287],loss: 0.004
# epoch : [17,387],loss: 0.004
# epoch : [17,487],loss: 0.004
# epoch : [17,587],loss: 0.004
# epoch : [17,687],loss: 0.004
# epoch : [17,787],loss: 0.004
# epoch : [17,887],loss: 0.004
# epoch : [17,987],loss: 0.004
# epoch : [17,1087],loss: 0.004
# epoch : [17,1187],loss: 0.004
# epoch : [17,1287],loss: 0.004
# epoch : [17,1387],loss: 0.004
# epoch : [17,1487],loss: 0.004
# epoch : [17,1587],loss: 0.004
# epoch : [17,1687],loss: 0.004
# epoch : [17,1787],loss: 0.004
# epoch : [17,1887],loss: 0.004
# epoch : [17,1987],loss: 0.004
# epoch : [17,2087],loss: 0.004
# epoch : [17,2187],loss: 0.004
# epoch : [17,2287],loss: 0.004
# epoch : [17,2387],loss: 0.004
# epoch : [17,2487],loss: 0.004
# epoch : [17,2587],loss: 0.004
# epoch : [17,2687],loss: 0.004
# epoch : [17,2787],loss: 0.004
# epoch : [17,2887],loss: 0.004
# epoch : [17,2987],loss: 0.004
# epoch : [17,3087],loss: 0.004
# epoch : [17,3187],loss: 0.004
# epoch : [17,3287],loss: 0.004
# epoch : [17,3387],loss: 0.004
# epoch : [17,3487],loss: 0.004
# epoch : [17,3587],loss: 0.004
# epoch : [17,3687],loss: 0.004
# epoch : [17,3787],loss: 0.004
# epoch : [17,3887],loss: 0.004
# epoch : [17,3987],loss: 0.004
# epoch : [17,4087],loss: 0.004
# epoch : [17,4187],loss: 0.004
# epoch : [17,4287],loss: 0.004
# epoch : [17,4387],loss: 0.004
# epoch : [17,4487],loss: 0.004
# epoch : [17,4587],loss: 0.004
# epoch : [17,4687],loss: 0.004
# epoch : [17,4787],loss: 0.004
# epoch : [17,4887],loss: 0.004
# epoch : [17,4987],loss: 0.004
# epoch : [17,5087],loss: 0.004
# epoch : [17,5187],loss: 0.004
# epoch : [17,5287],loss: 0.004
# epoch : [17,5387],loss: 0.004
# epoch : [17,5487],loss: 0.004
# epoch : [17,5587],loss: 0.004
# epoch : [17,5687],loss: 0.004
# epoch : [17,5787],loss: 0.004
# epoch : [17,5887],loss: 0.004
# epoch : [17,5987],loss: 0.004
# epoch : [17,6087],loss: 0.004
# epoch : [17,6187],loss: 0.004
# epoch : [17,6287],loss: 0.004
# epoch : [18,55],loss: 0.002
# epoch : [18,155],loss: 0.004
# epoch : [18,255],loss: 0.004
# epoch : [18,355],loss: 0.004
# epoch : [18,455],loss: 0.004
# epoch : [18,555],loss: 0.004
# epoch : [18,655],loss: 0.004
# epoch : [18,755],loss: 0.004
# epoch : [18,855],loss: 0.004
# epoch : [18,955],loss: 0.004
# epoch : [18,1055],loss: 0.004
# epoch : [18,1155],loss: 0.004
# epoch : [18,1255],loss: 0.004
# epoch : [18,1355],loss: 0.004
# epoch : [18,1455],loss: 0.004
# epoch : [18,1555],loss: 0.004
# epoch : [18,1655],loss: 0.004
# epoch : [18,1755],loss: 0.004
# epoch : [18,1855],loss: 0.004
# epoch : [18,1955],loss: 0.004
# epoch : [18,2055],loss: 0.004
# epoch : [18,2155],loss: 0.004
# epoch : [18,2255],loss: 0.004
# epoch : [18,2355],loss: 0.004
# epoch : [18,2455],loss: 0.004
# epoch : [18,2555],loss: 0.004
# epoch : [18,2655],loss: 0.004
# epoch : [18,2755],loss: 0.004
# epoch : [18,2855],loss: 0.004
# epoch : [18,2955],loss: 0.004
# epoch : [18,3055],loss: 0.004
# epoch : [18,3155],loss: 0.004
# epoch : [18,3255],loss: 0.004
# epoch : [18,3355],loss: 0.004
# epoch : [18,3455],loss: 0.004
# epoch : [18,3555],loss: 0.004
# epoch : [18,3655],loss: 0.004
# epoch : [18,3755],loss: 0.004
# epoch : [18,3855],loss: 0.004
# epoch : [18,3955],loss: 0.004
# epoch : [18,4055],loss: 0.004
# epoch : [18,4155],loss: 0.004
# epoch : [18,4255],loss: 0.004
# epoch : [18,4355],loss: 0.004
# epoch : [18,4455],loss: 0.004
# epoch : [18,4555],loss: 0.004
# epoch : [18,4655],loss: 0.004
# epoch : [18,4755],loss: 0.004
# epoch : [18,4855],loss: 0.004
# epoch : [18,4955],loss: 0.004
# epoch : [18,5055],loss: 0.004
# epoch : [18,5155],loss: 0.004
# epoch : [18,5255],loss: 0.004
# epoch : [18,5355],loss: 0.004
# epoch : [18,5455],loss: 0.004
# epoch : [18,5555],loss: 0.004
# epoch : [18,5655],loss: 0.004
# epoch : [18,5755],loss: 0.004
# epoch : [18,5855],loss: 0.004
# epoch : [18,5955],loss: 0.004
# epoch : [18,6055],loss: 0.004
# epoch : [18,6155],loss: 0.004
# epoch : [18,6255],loss: 0.004
# epoch : [19,23],loss: 0.001
# epoch : [19,123],loss: 0.004
# epoch : [19,223],loss: 0.004
# epoch : [19,323],loss: 0.004
# epoch : [19,423],loss: 0.004
# epoch : [19,523],loss: 0.004
# epoch : [19,623],loss: 0.004
# epoch : [19,723],loss: 0.004
# epoch : [19,823],loss: 0.004
# epoch : [19,923],loss: 0.004
# epoch : [19,1023],loss: 0.004
# epoch : [19,1123],loss: 0.004
# epoch : [19,1223],loss: 0.004
# epoch : [19,1323],loss: 0.004
# epoch : [19,1423],loss: 0.004
# epoch : [19,1523],loss: 0.004
# epoch : [19,1623],loss: 0.004
# epoch : [19,1723],loss: 0.004
# epoch : [19,1823],loss: 0.004
# epoch : [19,1923],loss: 0.004
# epoch : [19,2023],loss: 0.004
# epoch : [19,2123],loss: 0.004
# epoch : [19,2223],loss: 0.004
# epoch : [19,2323],loss: 0.004
# epoch : [19,2423],loss: 0.004
# epoch : [19,2523],loss: 0.004
# epoch : [19,2623],loss: 0.004
# epoch : [19,2723],loss: 0.004
# epoch : [19,2823],loss: 0.004
# epoch : [19,2923],loss: 0.004
# epoch : [19,3023],loss: 0.004
# epoch : [19,3123],loss: 0.004
# epoch : [19,3223],loss: 0.004
# epoch : [19,3323],loss: 0.004
# epoch : [19,3423],loss: 0.004
# epoch : [19,3523],loss: 0.004
# epoch : [19,3623],loss: 0.004
# epoch : [19,3723],loss: 0.004
# epoch : [19,3823],loss: 0.004
# epoch : [19,3923],loss: 0.004
# epoch : [19,4023],loss: 0.004
# epoch : [19,4123],loss: 0.004
# epoch : [19,4223],loss: 0.004
# epoch : [19,4323],loss: 0.004
# epoch : [19,4423],loss: 0.004
# epoch : [19,4523],loss: 0.004
# epoch : [19,4623],loss: 0.004
# epoch : [19,4723],loss: 0.004
# epoch : [19,4823],loss: 0.004
# epoch : [19,4923],loss: 0.004
# epoch : [19,5023],loss: 0.004
# epoch : [19,5123],loss: 0.004
# epoch : [19,5223],loss: 0.004
# epoch : [19,5323],loss: 0.004
# epoch : [19,5423],loss: 0.004
# epoch : [19,5523],loss: 0.004
# epoch : [19,5623],loss: 0.004
# epoch : [19,5723],loss: 0.004
# epoch : [19,5823],loss: 0.004
# epoch : [19,5923],loss: 0.004
# epoch : [19,6023],loss: 0.004
# epoch : [19,6123],loss: 0.004
# epoch : [19,6223],loss: 0.004
# epoch : [19,6323],loss: 0.004
# epoch : [20,91],loss: 0.004
# epoch : [20,191],loss: 0.004
# epoch : [20,291],loss: 0.004
# epoch : [20,391],loss: 0.004
# epoch : [20,491],loss: 0.004
# epoch : [20,591],loss: 0.004
# epoch : [20,691],loss: 0.004
# epoch : [20,791],loss: 0.004
# epoch : [20,891],loss: 0.004
# epoch : [20,991],loss: 0.004
# epoch : [20,1091],loss: 0.004
# epoch : [20,1191],loss: 0.004
# epoch : [20,1291],loss: 0.004
# epoch : [20,1391],loss: 0.004
# epoch : [20,1491],loss: 0.004
# epoch : [20,1591],loss: 0.004
# epoch : [20,1691],loss: 0.004
# epoch : [20,1791],loss: 0.004
# epoch : [20,1891],loss: 0.004
# epoch : [20,1991],loss: 0.004
# epoch : [20,2091],loss: 0.004
# epoch : [20,2191],loss: 0.004
# epoch : [20,2291],loss: 0.004
# epoch : [20,2391],loss: 0.004
# epoch : [20,2491],loss: 0.004
# epoch : [20,2591],loss: 0.004
# epoch : [20,2691],loss: 0.004
# epoch : [20,2791],loss: 0.004
# epoch : [20,2891],loss: 0.004
# epoch : [20,2991],loss: 0.004
# epoch : [20,3091],loss: 0.004
# epoch : [20,3191],loss: 0.004
# epoch : [20,3291],loss: 0.004
# epoch : [20,3391],loss: 0.004
# epoch : [20,3491],loss: 0.004
# epoch : [20,3591],loss: 0.004
# epoch : [20,3691],loss: 0.004
# epoch : [20,3791],loss: 0.004
# epoch : [20,3891],loss: 0.004
# epoch : [20,3991],loss: 0.004
# epoch : [20,4091],loss: 0.004
# epoch : [20,4191],loss: 0.004
# epoch : [20,4291],loss: 0.004
# epoch : [20,4391],loss: 0.004
# epoch : [20,4491],loss: 0.004
# epoch : [20,4591],loss: 0.004
# epoch : [20,4691],loss: 0.004
# epoch : [20,4791],loss: 0.004
# epoch : [20,4891],loss: 0.004
# epoch : [20,4991],loss: 0.004
# epoch : [20,5091],loss: 0.004
# epoch : [20,5191],loss: 0.004
# epoch : [20,5291],loss: 0.004
# epoch : [20,5391],loss: 0.004
# epoch : [20,5491],loss: 0.004
# epoch : [20,5591],loss: 0.004
# epoch : [20,5691],loss: 0.004
# epoch : [20,5791],loss: 0.004
# epoch : [20,5891],loss: 0.004
# epoch : [20,5991],loss: 0.004
# epoch : [20,6091],loss: 0.004
# epoch : [20,6191],loss: 0.004
# epoch : [20,6291],loss: 0.004
# epoch : [21,59],loss: 0.002
# epoch : [21,159],loss: 0.004
# epoch : [21,259],loss: 0.004
# epoch : [21,359],loss: 0.004
# epoch : [21,459],loss: 0.004
# epoch : [21,559],loss: 0.004
# epoch : [21,659],loss: 0.004
# epoch : [21,759],loss: 0.004
# epoch : [21,859],loss: 0.004
# epoch : [21,959],loss: 0.004
# epoch : [21,1059],loss: 0.004
# epoch : [21,1159],loss: 0.004
# epoch : [21,1259],loss: 0.004
# epoch : [21,1359],loss: 0.004
# epoch : [21,1459],loss: 0.004
# epoch : [21,1559],loss: 0.004
# epoch : [21,1659],loss: 0.004
# epoch : [21,1759],loss: 0.004
# epoch : [21,1859],loss: 0.004
# epoch : [21,1959],loss: 0.004
# epoch : [21,2059],loss: 0.004
# epoch : [21,2159],loss: 0.004
# epoch : [21,2259],loss: 0.004
# epoch : [21,2359],loss: 0.004
# epoch : [21,2459],loss: 0.004
# epoch : [21,2559],loss: 0.004
# epoch : [21,2659],loss: 0.004
# epoch : [21,2759],loss: 0.004
# epoch : [21,2859],loss: 0.004
# epoch : [21,2959],loss: 0.004
# epoch : [21,3059],loss: 0.004
# epoch : [21,3159],loss: 0.004
# epoch : [21,3259],loss: 0.004
# epoch : [21,3359],loss: 0.004
# epoch : [21,3459],loss: 0.004
# epoch : [21,3559],loss: 0.004
# epoch : [21,3659],loss: 0.004
# epoch : [21,3759],loss: 0.004
# epoch : [21,3859],loss: 0.004
# epoch : [21,3959],loss: 0.004
# epoch : [21,4059],loss: 0.004
# epoch : [21,4159],loss: 0.004
# epoch : [21,4259],loss: 0.004
# epoch : [21,4359],loss: 0.004
# epoch : [21,4459],loss: 0.004
# epoch : [21,4559],loss: 0.004
# epoch : [21,4659],loss: 0.004
# epoch : [21,4759],loss: 0.004
# epoch : [21,4859],loss: 0.004
# epoch : [21,4959],loss: 0.004
# epoch : [21,5059],loss: 0.004
# epoch : [21,5159],loss: 0.004
# epoch : [21,5259],loss: 0.004
# epoch : [21,5359],loss: 0.004
# epoch : [21,5459],loss: 0.004
# epoch : [21,5559],loss: 0.004
# epoch : [21,5659],loss: 0.004
# epoch : [21,5759],loss: 0.004
# epoch : [21,5859],loss: 0.004
# epoch : [21,5959],loss: 0.004
# epoch : [21,6059],loss: 0.004
# epoch : [21,6159],loss: 0.004
# epoch : [21,6259],loss: 0.004
# epoch : [22,27],loss: 0.001
# epoch : [22,127],loss: 0.004
# epoch : [22,227],loss: 0.004
# epoch : [22,327],loss: 0.004
# epoch : [22,427],loss: 0.004
# epoch : [22,527],loss: 0.004
# epoch : [22,627],loss: 0.004
# epoch : [22,727],loss: 0.004
# epoch : [22,827],loss: 0.004
# epoch : [22,927],loss: 0.004
# epoch : [22,1027],loss: 0.004
# epoch : [22,1127],loss: 0.004
# epoch : [22,1227],loss: 0.004
# epoch : [22,1327],loss: 0.004
# epoch : [22,1427],loss: 0.004
# epoch : [22,1527],loss: 0.004
# epoch : [22,1627],loss: 0.004
# epoch : [22,1727],loss: 0.004
# epoch : [22,1827],loss: 0.004
# epoch : [22,1927],loss: 0.004
# epoch : [22,2027],loss: 0.004
# epoch : [22,2127],loss: 0.004
# epoch : [22,2227],loss: 0.004
# epoch : [22,2327],loss: 0.004
# epoch : [22,2427],loss: 0.004
# epoch : [22,2527],loss: 0.004
# epoch : [22,2627],loss: 0.004
# epoch : [22,2727],loss: 0.004
# epoch : [22,2827],loss: 0.004
# epoch : [22,2927],loss: 0.004
# epoch : [22,3027],loss: 0.004
# epoch : [22,3127],loss: 0.004
# epoch : [22,3227],loss: 0.004
# epoch : [22,3327],loss: 0.004
# epoch : [22,3427],loss: 0.004
# epoch : [22,3527],loss: 0.004
# epoch : [22,3627],loss: 0.004
# epoch : [22,3727],loss: 0.004
# epoch : [22,3827],loss: 0.004
# epoch : [22,3927],loss: 0.004
# epoch : [22,4027],loss: 0.004
# epoch : [22,4127],loss: 0.004
# epoch : [22,4227],loss: 0.004
# epoch : [22,4327],loss: 0.004
# epoch : [22,4427],loss: 0.004
# epoch : [22,4527],loss: 0.004
# epoch : [22,4627],loss: 0.004
# epoch : [22,4727],loss: 0.004
# epoch : [22,4827],loss: 0.004
# epoch : [22,4927],loss: 0.004
# epoch : [22,5027],loss: 0.004
# epoch : [22,5127],loss: 0.004
# epoch : [22,5227],loss: 0.004
# epoch : [22,5327],loss: 0.004
# epoch : [22,5427],loss: 0.004
# epoch : [22,5527],loss: 0.004
# epoch : [22,5627],loss: 0.004
# epoch : [22,5727],loss: 0.004
# epoch : [22,5827],loss: 0.004
# epoch : [22,5927],loss: 0.004
# epoch : [22,6027],loss: 0.004
# epoch : [22,6127],loss: 0.004
# epoch : [22,6227],loss: 0.004
# epoch : [22,6327],loss: 0.004
# epoch : [23,95],loss: 0.004
# epoch : [23,195],loss: 0.004
# epoch : [23,295],loss: 0.004
# epoch : [23,395],loss: 0.004
# epoch : [23,495],loss: 0.004
# epoch : [23,595],loss: 0.004
# epoch : [23,695],loss: 0.004
# epoch : [23,795],loss: 0.004
# epoch : [23,895],loss: 0.004
# epoch : [23,995],loss: 0.004
# epoch : [23,1095],loss: 0.004
# epoch : [23,1195],loss: 0.004
# epoch : [23,1295],loss: 0.004
# epoch : [23,1395],loss: 0.004
# epoch : [23,1495],loss: 0.004
# epoch : [23,1595],loss: 0.004
# epoch : [23,1695],loss: 0.004
# epoch : [23,1795],loss: 0.004
# epoch : [23,1895],loss: 0.004
# epoch : [23,1995],loss: 0.004
# epoch : [23,2095],loss: 0.004
# epoch : [23,2195],loss: 0.004
# epoch : [23,2295],loss: 0.004
# epoch : [23,2395],loss: 0.004
# epoch : [23,2495],loss: 0.004
# epoch : [23,2595],loss: 0.004
# epoch : [23,2695],loss: 0.004
# epoch : [23,2795],loss: 0.004
# epoch : [23,2895],loss: 0.004
# epoch : [23,2995],loss: 0.004
# epoch : [23,3095],loss: 0.004
# epoch : [23,3195],loss: 0.004
# epoch : [23,3295],loss: 0.004
# epoch : [23,3395],loss: 0.004
# epoch : [23,3495],loss: 0.004
# epoch : [23,3595],loss: 0.004
# epoch : [23,3695],loss: 0.004
# epoch : [23,3795],loss: 0.004
# epoch : [23,3895],loss: 0.004
# epoch : [23,3995],loss: 0.004
# epoch : [23,4095],loss: 0.004
# epoch : [23,4195],loss: 0.004
# epoch : [23,4295],loss: 0.004
# epoch : [23,4395],loss: 0.004
# epoch : [23,4495],loss: 0.004
# epoch : [23,4595],loss: 0.004
# epoch : [23,4695],loss: 0.004
# epoch : [23,4795],loss: 0.004
# epoch : [23,4895],loss: 0.004
# epoch : [23,4995],loss: 0.004
# epoch : [23,5095],loss: 0.004
# epoch : [23,5195],loss: 0.004
# epoch : [23,5295],loss: 0.004
# epoch : [23,5395],loss: 0.004
# epoch : [23,5495],loss: 0.004
# epoch : [23,5595],loss: 0.004
# epoch : [23,5695],loss: 0.004
# epoch : [23,5795],loss: 0.004
# epoch : [23,5895],loss: 0.004
# epoch : [23,5995],loss: 0.004
# epoch : [23,6095],loss: 0.004
# epoch : [23,6195],loss: 0.004
# epoch : [23,6295],loss: 0.004
# epoch : [24,63],loss: 0.003
# epoch : [24,163],loss: 0.004
# epoch : [24,263],loss: 0.004
# epoch : [24,363],loss: 0.004
# epoch : [24,463],loss: 0.004
# epoch : [24,563],loss: 0.004
# epoch : [24,663],loss: 0.004
# epoch : [24,763],loss: 0.004
# epoch : [24,863],loss: 0.004
# epoch : [24,963],loss: 0.004
# epoch : [24,1063],loss: 0.004
# epoch : [24,1163],loss: 0.004
# epoch : [24,1263],loss: 0.004
# epoch : [24,1363],loss: 0.004
# epoch : [24,1463],loss: 0.004
# epoch : [24,1563],loss: 0.004
# epoch : [24,1663],loss: 0.004
# epoch : [24,1763],loss: 0.004
# epoch : [24,1863],loss: 0.004
# epoch : [24,1963],loss: 0.004
# epoch : [24,2063],loss: 0.004
# epoch : [24,2163],loss: 0.004
# epoch : [24,2263],loss: 0.004
# epoch : [24,2363],loss: 0.004
# epoch : [24,2463],loss: 0.004
# epoch : [24,2563],loss: 0.004
# epoch : [24,2663],loss: 0.004
# epoch : [24,2763],loss: 0.004
# epoch : [24,2863],loss: 0.004
# epoch : [24,2963],loss: 0.004
# epoch : [24,3063],loss: 0.004
# epoch : [24,3163],loss: 0.004
# epoch : [24,3263],loss: 0.004
# epoch : [24,3363],loss: 0.004
# epoch : [24,3463],loss: 0.004
# epoch : [24,3563],loss: 0.004
# epoch : [24,3663],loss: 0.004
# epoch : [24,3763],loss: 0.004
# epoch : [24,3863],loss: 0.004
# epoch : [24,3963],loss: 0.004
# epoch : [24,4063],loss: 0.004
# epoch : [24,4163],loss: 0.004
# epoch : [24,4263],loss: 0.004
# epoch : [24,4363],loss: 0.004
# epoch : [24,4463],loss: 0.004
# epoch : [24,4563],loss: 0.004
# epoch : [24,4663],loss: 0.004
# epoch : [24,4763],loss: 0.004
# epoch : [24,4863],loss: 0.004
# epoch : [24,4963],loss: 0.004
# epoch : [24,5063],loss: 0.004
# epoch : [24,5163],loss: 0.004
# epoch : [24,5263],loss: 0.004
# epoch : [24,5363],loss: 0.004
# epoch : [24,5463],loss: 0.004
# epoch : [24,5563],loss: 0.004
# epoch : [24,5663],loss: 0.004
# epoch : [24,5763],loss: 0.004
# epoch : [24,5863],loss: 0.004
# epoch : [24,5963],loss: 0.004
# epoch : [24,6063],loss: 0.004
# epoch : [24,6163],loss: 0.004
# epoch : [24,6263],loss: 0.004
# epoch : [25,31],loss: 0.001
# epoch : [25,131],loss: 0.004
# epoch : [25,231],loss: 0.004
# epoch : [25,331],loss: 0.004
# epoch : [25,431],loss: 0.004
# epoch : [25,531],loss: 0.004
# epoch : [25,631],loss: 0.004
# epoch : [25,731],loss: 0.004
# epoch : [25,831],loss: 0.004
# epoch : [25,931],loss: 0.004
# epoch : [25,1031],loss: 0.004
# epoch : [25,1131],loss: 0.004
# epoch : [25,1231],loss: 0.004
# epoch : [25,1331],loss: 0.004
# epoch : [25,1431],loss: 0.004
# epoch : [25,1531],loss: 0.004
# epoch : [25,1631],loss: 0.004
# epoch : [25,1731],loss: 0.004
# epoch : [25,1831],loss: 0.004
# epoch : [25,1931],loss: 0.004
# epoch : [25,2031],loss: 0.004
# epoch : [25,2131],loss: 0.004
# epoch : [25,2231],loss: 0.004
# epoch : [25,2331],loss: 0.004
# epoch : [25,2431],loss: 0.004
# epoch : [25,2531],loss: 0.004
# epoch : [25,2631],loss: 0.004
# epoch : [25,2731],loss: 0.004
# epoch : [25,2831],loss: 0.004
# epoch : [25,2931],loss: 0.004
# epoch : [25,3031],loss: 0.004
# epoch : [25,3131],loss: 0.004
# epoch : [25,3231],loss: 0.004
# epoch : [25,3331],loss: 0.004
# epoch : [25,3431],loss: 0.004
# epoch : [25,3531],loss: 0.004
# epoch : [25,3631],loss: 0.004
# epoch : [25,3731],loss: 0.004
# epoch : [25,3831],loss: 0.004
# epoch : [25,3931],loss: 0.004
# epoch : [25,4031],loss: 0.004
# epoch : [25,4131],loss: 0.004
# epoch : [25,4231],loss: 0.004
# epoch : [25,4331],loss: 0.004
# epoch : [25,4431],loss: 0.004
# epoch : [25,4531],loss: 0.004
# epoch : [25,4631],loss: 0.004
# epoch : [25,4731],loss: 0.004
# epoch : [25,4831],loss: 0.004
# epoch : [25,4931],loss: 0.004
# epoch : [25,5031],loss: 0.004
# epoch : [25,5131],loss: 0.004
# epoch : [25,5231],loss: 0.004
# epoch : [25,5331],loss: 0.004
# epoch : [25,5431],loss: 0.004
# epoch : [25,5531],loss: 0.004
# epoch : [25,5631],loss: 0.004
# epoch : [25,5731],loss: 0.004
# epoch : [25,5831],loss: 0.004
# epoch : [25,5931],loss: 0.004
# epoch : [25,6031],loss: 0.004
# epoch : [25,6131],loss: 0.004
# epoch : [25,6231],loss: 0.004
# epoch : [25,6331],loss: 0.004
# epoch : [26,99],loss: 0.004
# epoch : [26,199],loss: 0.004
# epoch : [26,299],loss: 0.004
# epoch : [26,399],loss: 0.004
# epoch : [26,499],loss: 0.004
# epoch : [26,599],loss: 0.004
# epoch : [26,699],loss: 0.004
# epoch : [26,799],loss: 0.004
# epoch : [26,899],loss: 0.004
# epoch : [26,999],loss: 0.004
# epoch : [26,1099],loss: 0.004
# epoch : [26,1199],loss: 0.004
# epoch : [26,1299],loss: 0.004
# epoch : [26,1399],loss: 0.004
# epoch : [26,1499],loss: 0.004
# epoch : [26,1599],loss: 0.004
# epoch : [26,1699],loss: 0.004
# epoch : [26,1799],loss: 0.004
# epoch : [26,1899],loss: 0.004
# epoch : [26,1999],loss: 0.004
# epoch : [26,2099],loss: 0.004
# epoch : [26,2199],loss: 0.004
# epoch : [26,2299],loss: 0.004
# epoch : [26,2399],loss: 0.004
# epoch : [26,2499],loss: 0.004
# epoch : [26,2599],loss: 0.004
# epoch : [26,2699],loss: 0.004
# epoch : [26,2799],loss: 0.004
# epoch : [26,2899],loss: 0.004
# epoch : [26,2999],loss: 0.004
# epoch : [26,3099],loss: 0.004
# epoch : [26,3199],loss: 0.004
# epoch : [26,3299],loss: 0.004
# epoch : [26,3399],loss: 0.004
# epoch : [26,3499],loss: 0.004
# epoch : [26,3599],loss: 0.004
# epoch : [26,3699],loss: 0.004
# epoch : [26,3799],loss: 0.004
# epoch : [26,3899],loss: 0.004
# epoch : [26,3999],loss: 0.004
# epoch : [26,4099],loss: 0.004
# epoch : [26,4199],loss: 0.004
# epoch : [26,4299],loss: 0.004
# epoch : [26,4399],loss: 0.004
# epoch : [26,4499],loss: 0.004
# ...
# epoch : [123,1595],loss: 0.004
# epoch : [123,1695],loss: 0.004
# epoch : [123,1795],loss: 0.004
# epoch : [123,1895],loss: 0.004
# epoch : [123,1995],loss: 0.004
# epoch : [123,2095],loss: 0.004
# epoch : [123,2195],loss: 0.004
# epoch : [123,2295],loss: 0.004
# epoch : [123,2395],loss: 0.004
# epoch : [123,2495],loss: 0.004
# epoch : [123,2595],loss: 0.004
# epoch : [123,2695],loss: 0.004
# epoch : [123,2795],loss: 0.004
# epoch : [123,2895],loss: 0.004
# epoch : [123,2995],loss: 0.004
# epoch : [123,3095],loss: 0.004
# epoch : [123,3195],loss: 0.004
# epoch : [123,3295],loss: 0.004
# epoch : [123,3395],loss: 0.004
# epoch : [123,3495],loss: 0.004
# epoch : [123,3595],loss: 0.004
# epoch : [123,3695],loss: 0.004
# epoch : [123,3795],loss: 0.004
# epoch : [123,3895],loss: 0.004
# epoch : [123,3995],loss: 0.004
# epoch : [123,4095],loss: 0.004
# epoch : [123,4195],loss: 0.004
# epoch : [123,4295],loss: 0.004
# epoch : [123,4395],loss: 0.004
# epoch : [123,4495],loss: 0.004
# epoch : [123,4595],loss: 0.004
# epoch : [123,4695],loss: 0.004
# epoch : [123,4795],loss: 0.004
# epoch : [123,4895],loss: 0.004
# epoch : [123,4995],loss: 0.004
# epoch : [123,5095],loss: 0.004
# epoch : [123,5195],loss: 0.004
# epoch : [123,5295],loss: 0.004
# epoch : [123,5395],loss: 0.004
# epoch : [123,5495],loss: 0.004
# epoch : [123,5595],loss: 0.004
# epoch : [123,5695],loss: 0.004
# epoch : [123,5795],loss: 0.004
# epoch : [123,5895],loss: 0.004
# epoch : [123,5995],loss: 0.004
# epoch : [123,6095],loss: 0.004
# epoch : [123,6195],loss: 0.004
# epoch : [123,6295],loss: 0.004
# epoch : [124,63],loss: 0.003
# epoch : [124,163],loss: 0.004
# epoch : [124,263],loss: 0.004
# epoch : [124,363],loss: 0.004
# epoch : [124,463],loss: 0.004
# epoch : [124,563],loss: 0.004
# epoch : [124,663],loss: 0.004
# epoch : [124,763],loss: 0.004
# epoch : [124,863],loss: 0.004
# epoch : [124,963],loss: 0.004
# epoch : [124,1063],loss: 0.004
# epoch : [124,1163],loss: 0.004
# epoch : [124,1263],loss: 0.004
# epoch : [124,1363],loss: 0.004
# epoch : [124,1463],loss: 0.004
# epoch : [124,1563],loss: 0.004
# epoch : [124,1663],loss: 0.004
# epoch : [124,1763],loss: 0.004
# epoch : [124,1863],loss: 0.004
# epoch : [124,1963],loss: 0.004
# epoch : [124,2063],loss: 0.004
# epoch : [124,2163],loss: 0.004
# epoch : [124,2263],loss: 0.004
# epoch : [124,2363],loss: 0.004
# epoch : [124,2463],loss: 0.004
# epoch : [124,2563],loss: 0.004
# epoch : [124,2663],loss: 0.004
# epoch : [124,2763],loss: 0.004
# epoch : [124,2863],loss: 0.004
# epoch : [124,2963],loss: 0.004
# epoch : [124,3063],loss: 0.004
# epoch : [124,3163],loss: 0.004
# epoch : [124,3263],loss: 0.004
# epoch : [124,3363],loss: 0.004
# epoch : [124,3463],loss: 0.004
# epoch : [124,3563],loss: 0.004
# epoch : [124,3663],loss: 0.004
# epoch : [124,3763],loss: 0.004
# epoch : [124,3863],loss: 0.004
# epoch : [124,3963],loss: 0.004
# epoch : [124,4063],loss: 0.004
# epoch : [124,4163],loss: 0.004
# epoch : [124,4263],loss: 0.004
# epoch : [124,4363],loss: 0.004
# epoch : [124,4463],loss: 0.004
# epoch : [124,4563],loss: 0.004
# epoch : [124,4663],loss: 0.004
# epoch : [124,4763],loss: 0.004
# epoch : [124,4863],loss: 0.004
# epoch : [124,4963],loss: 0.004
# epoch : [124,5063],loss: 0.004
# epoch : [124,5163],loss: 0.004
# epoch : [124,5263],loss: 0.004
# epoch : [124,5363],loss: 0.004
# epoch : [124,5463],loss: 0.004
# epoch : [124,5563],loss: 0.004
# epoch : [124,5663],loss: 0.004
# epoch : [124,5763],loss: 0.004
# epoch : [124,5863],loss: 0.004
# epoch : [124,5963],loss: 0.004
# epoch : [124,6063],loss: 0.004
# epoch : [124,6163],loss: 0.004
# epoch : [124,6263],loss: 0.004
# epoch : [125,31],loss: 0.001
# epoch : [125,131],loss: 0.004
# epoch : [125,231],loss: 0.004
# epoch : [125,331],loss: 0.004
# epoch : [125,431],loss: 0.004
# epoch : [125,531],loss: 0.004
# epoch : [125,631],loss: 0.004
# epoch : [125,731],loss: 0.004
# epoch : [125,831],loss: 0.004
# epoch : [125,931],loss: 0.004
# epoch : [125,1031],loss: 0.004
# epoch : [125,1131],loss: 0.004
# epoch : [125,1231],loss: 0.004
# epoch : [125,1331],loss: 0.004
# epoch : [125,1431],loss: 0.004
# epoch : [125,1531],loss: 0.004
# epoch : [125,1631],loss: 0.004
# epoch : [125,1731],loss: 0.004
# epoch : [125,1831],loss: 0.004
# epoch : [125,1931],loss: 0.004
# epoch : [125,2031],loss: 0.004
# epoch : [125,2131],loss: 0.004
# epoch : [125,2231],loss: 0.004
# epoch : [125,2331],loss: 0.004
# epoch : [125,2431],loss: 0.004
# epoch : [125,2531],loss: 0.004
# epoch : [125,2631],loss: 0.004
# epoch : [125,2731],loss: 0.004
# epoch : [125,2831],loss: 0.004
# epoch : [125,2931],loss: 0.004
# epoch : [125,3031],loss: 0.004
# epoch : [125,3131],loss: 0.004
# epoch : [125,3231],loss: 0.004
# epoch : [125,3331],loss: 0.004
# epoch : [125,3431],loss: 0.004
# epoch : [125,3531],loss: 0.004
# epoch : [125,3631],loss: 0.004
# epoch : [125,3731],loss: 0.004
# epoch : [125,3831],loss: 0.004
# epoch : [125,3931],loss: 0.004
# epoch : [125,4031],loss: 0.004
# epoch : [125,4131],loss: 0.004
# epoch : [125,4231],loss: 0.004
# epoch : [125,4331],loss: 0.004
# epoch : [125,4431],loss: 0.004
# epoch : [125,4531],loss: 0.004
# epoch : [125,4631],loss: 0.004
# epoch : [125,4731],loss: 0.004
# epoch : [125,4831],loss: 0.004
# epoch : [125,4931],loss: 0.004
# epoch : [125,5031],loss: 0.004
# epoch : [125,5131],loss: 0.004
# epoch : [125,5231],loss: 0.004
# epoch : [125,5331],loss: 0.004
# epoch : [125,5431],loss: 0.004
# epoch : [125,5531],loss: 0.004
# epoch : [125,5631],loss: 0.004
# epoch : [125,5731],loss: 0.004
# epoch : [125,5831],loss: 0.004
# epoch : [125,5931],loss: 0.004
# epoch : [125,6031],loss: 0.004
# epoch : [125,6131],loss: 0.004
# epoch : [125,6231],loss: 0.004
# epoch : [125,6331],loss: 0.004
# epoch : [126,99],loss: 0.004
# epoch : [126,199],loss: 0.004
# epoch : [126,299],loss: 0.004
# epoch : [126,399],loss: 0.004
# epoch : [126,499],loss: 0.004
# epoch : [126,599],loss: 0.004
# epoch : [126,699],loss: 0.004
# epoch : [126,799],loss: 0.004
# epoch : [126,899],loss: 0.004
# epoch : [126,999],loss: 0.004
# epoch : [126,1099],loss: 0.004
# epoch : [126,1199],loss: 0.004
# epoch : [126,1299],loss: 0.004
# epoch : [126,1399],loss: 0.004
# epoch : [126,1499],loss: 0.004
# epoch : [126,1599],loss: 0.004
# epoch : [126,1699],loss: 0.004
# epoch : [126,1799],loss: 0.004
# epoch : [126,1899],loss: 0.004
# epoch : [126,1999],loss: 0.004
# epoch : [126,2099],loss: 0.004
# epoch : [126,2199],loss: 0.004
# epoch : [126,2299],loss: 0.004
# epoch : [126,2399],loss: 0.004
# epoch : [126,2499],loss: 0.004
# epoch : [126,2599],loss: 0.004
# epoch : [126,2699],loss: 0.004
# epoch : [126,2799],loss: 0.004
# epoch : [126,2899],loss: 0.004
# epoch : [126,2999],loss: 0.004
# epoch : [126,3099],loss: 0.004
# epoch : [126,3199],loss: 0.004
# epoch : [126,3299],loss: 0.004
# epoch : [126,3399],loss: 0.004
# epoch : [126,3499],loss: 0.004
# epoch : [126,3599],loss: 0.004
# epoch : [126,3699],loss: 0.004
# epoch : [126,3799],loss: 0.004
# epoch : [126,3899],loss: 0.004
# epoch : [126,3999],loss: 0.004
# epoch : [126,4099],loss: 0.004
# epoch : [126,4199],loss: 0.004
# epoch : [126,4299],loss: 0.004
# epoch : [126,4399],loss: 0.004
# epoch : [126,4499],loss: 0.004
# epoch : [126,4599],loss: 0.004
# epoch : [126,4699],loss: 0.004
# epoch : [126,4799],loss: 0.004
# epoch : [126,4899],loss: 0.004
# epoch : [126,4999],loss: 0.004
# epoch : [126,5099],loss: 0.004
# epoch : [126,5199],loss: 0.004
# epoch : [126,5299],loss: 0.004
# epoch : [126,5399],loss: 0.004
# epoch : [126,5499],loss: 0.004
# epoch : [126,5599],loss: 0.004
# epoch : [126,5699],loss: 0.004
# epoch : [126,5799],loss: 0.004
# epoch : [126,5899],loss: 0.004
# epoch : [126,5999],loss: 0.004
# epoch : [126,6099],loss: 0.004
# epoch : [126,6199],loss: 0.004
# epoch : [126,6299],loss: 0.004
# epoch : [127,67],loss: 0.003
# epoch : [127,167],loss: 0.004
# epoch : [127,267],loss: 0.004
# epoch : [127,367],loss: 0.004
# epoch : [127,467],loss: 0.004
# epoch : [127,567],loss: 0.004
# epoch : [127,667],loss: 0.004
# epoch : [127,767],loss: 0.004
# epoch : [127,867],loss: 0.004
# epoch : [127,967],loss: 0.004
# epoch : [127,1067],loss: 0.004
# epoch : [127,1167],loss: 0.004
# epoch : [127,1267],loss: 0.004
# epoch : [127,1367],loss: 0.004
# epoch : [127,1467],loss: 0.004
# epoch : [127,1567],loss: 0.004
# epoch : [127,1667],loss: 0.004
# epoch : [127,1767],loss: 0.004
# epoch : [127,1867],loss: 0.004
# epoch : [127,1967],loss: 0.004
# epoch : [127,2067],loss: 0.004
# epoch : [127,2167],loss: 0.004
# epoch : [127,2267],loss: 0.004
# epoch : [127,2367],loss: 0.004
# epoch : [127,2467],loss: 0.004
# epoch : [127,2567],loss: 0.004
# epoch : [127,2667],loss: 0.004
# epoch : [127,2767],loss: 0.004
# epoch : [127,2867],loss: 0.004
# epoch : [127,2967],loss: 0.004
# epoch : [127,3067],loss: 0.004
# epoch : [127,3167],loss: 0.004
# epoch : [127,3267],loss: 0.004
# epoch : [127,3367],loss: 0.004
# epoch : [127,3467],loss: 0.004
# epoch : [127,3567],loss: 0.004
# epoch : [127,3667],loss: 0.004
# epoch : [127,3767],loss: 0.004
# epoch : [127,3867],loss: 0.004
# epoch : [127,3967],loss: 0.004
# epoch : [127,4067],loss: 0.004
# epoch : [127,4167],loss: 0.004
# epoch : [127,4267],loss: 0.004
# epoch : [127,4367],loss: 0.004
# epoch : [127,4467],loss: 0.004
# epoch : [127,4567],loss: 0.004
# epoch : [127,4667],loss: 0.004
# epoch : [127,4767],loss: 0.004
# epoch : [127,4867],loss: 0.004
# epoch : [127,4967],loss: 0.004
# epoch : [127,5067],loss: 0.004
# epoch : [127,5167],loss: 0.004
# epoch : [127,5267],loss: 0.004
# epoch : [127,5367],loss: 0.004
# epoch : [127,5467],loss: 0.004
# epoch : [127,5567],loss: 0.004
# epoch : [127,5667],loss: 0.004
# epoch : [127,5767],loss: 0.004
# epoch : [127,5867],loss: 0.004
# epoch : [127,5967],loss: 0.004
# epoch : [127,6067],loss: 0.004
# epoch : [127,6167],loss: 0.004
# epoch : [127,6267],loss: 0.004
# epoch : [128,35],loss: 0.001
# epoch : [128,135],loss: 0.004
# epoch : [128,235],loss: 0.004
# epoch : [128,335],loss: 0.004
# epoch : [128,435],loss: 0.004
# epoch : [128,535],loss: 0.004
# epoch : [128,635],loss: 0.004
# epoch : [128,735],loss: 0.004
# epoch : [128,835],loss: 0.004
# epoch : [128,935],loss: 0.004
# epoch : [128,1035],loss: 0.004
# epoch : [128,1135],loss: 0.004
# epoch : [128,1235],loss: 0.004
# epoch : [128,1335],loss: 0.004
# epoch : [128,1435],loss: 0.004
# epoch : [128,1535],loss: 0.004
# epoch : [128,1635],loss: 0.004
# epoch : [128,1735],loss: 0.004
# epoch : [128,1835],loss: 0.004
# epoch : [128,1935],loss: 0.004
# epoch : [128,2035],loss: 0.004
# epoch : [128,2135],loss: 0.004
# epoch : [128,2235],loss: 0.004
# epoch : [128,2335],loss: 0.004
# epoch : [128,2435],loss: 0.004
# epoch : [128,2535],loss: 0.004
# epoch : [128,2635],loss: 0.004
# epoch : [128,2735],loss: 0.004
# epoch : [128,2835],loss: 0.004
# epoch : [128,2935],loss: 0.004
# epoch : [128,3035],loss: 0.004
# epoch : [128,3135],loss: 0.004
# epoch : [128,3235],loss: 0.004
# epoch : [128,3335],loss: 0.004
# epoch : [128,3435],loss: 0.004
# epoch : [128,3535],loss: 0.004
# epoch : [128,3635],loss: 0.004
# epoch : [128,3735],loss: 0.004
# epoch : [128,3835],loss: 0.004
# epoch : [128,3935],loss: 0.004
# epoch : [128,4035],loss: 0.004
# epoch : [128,4135],loss: 0.004
# epoch : [128,4235],loss: 0.004
# epoch : [128,4335],loss: 0.004
# epoch : [128,4435],loss: 0.004
# epoch : [128,4535],loss: 0.004
# epoch : [128,4635],loss: 0.004
# epoch : [128,4735],loss: 0.004
# epoch : [128,4835],loss: 0.004
# epoch : [128,4935],loss: 0.004
# epoch : [128,5035],loss: 0.004
# epoch : [128,5135],loss: 0.004
# epoch : [128,5235],loss: 0.004
# epoch : [128,5335],loss: 0.004
# epoch : [128,5435],loss: 0.004
# epoch : [128,5535],loss: 0.004
# epoch : [128,5635],loss: 0.004
# epoch : [128,5735],loss: 0.004
# epoch : [128,5835],loss: 0.004
# epoch : [128,5935],loss: 0.004
# epoch : [128,6035],loss: 0.004
# epoch : [128,6135],loss: 0.004
# epoch : [128,6235],loss: 0.004
# epoch : [129,3],loss: 0.000
# epoch : [129,103],loss: 0.004
# epoch : [129,203],loss: 0.004
# epoch : [129,303],loss: 0.004
# epoch : [129,403],loss: 0.004
# epoch : [129,503],loss: 0.004
# epoch : [129,603],loss: 0.004
# epoch : [129,703],loss: 0.004
# epoch : [129,803],loss: 0.004
# epoch : [129,903],loss: 0.004
# epoch : [129,1003],loss: 0.004
# epoch : [129,1103],loss: 0.004
# epoch : [129,1203],loss: 0.004
# epoch : [129,1303],loss: 0.004
# epoch : [129,1403],loss: 0.004
# epoch : [129,1503],loss: 0.004
# epoch : [129,1603],loss: 0.004
# epoch : [129,1703],loss: 0.004
# epoch : [129,1803],loss: 0.004
# epoch : [129,1903],loss: 0.004
# epoch : [129,2003],loss: 0.004
# epoch : [129,2103],loss: 0.004
# epoch : [129,2203],loss: 0.004
# epoch : [129,2303],loss: 0.004
# epoch : [129,2403],loss: 0.004
# epoch : [129,2503],loss: 0.004
# epoch : [129,2603],loss: 0.004
# epoch : [129,2703],loss: 0.004
# epoch : [129,2803],loss: 0.004
# epoch : [129,2903],loss: 0.004
# epoch : [129,3003],loss: 0.004
# epoch : [129,3103],loss: 0.004
# epoch : [129,3203],loss: 0.004
# epoch : [129,3303],loss: 0.004
# epoch : [129,3403],loss: 0.004
# epoch : [129,3503],loss: 0.004
# epoch : [129,3603],loss: 0.004
# epoch : [129,3703],loss: 0.004
# epoch : [129,3803],loss: 0.004
# epoch : [129,3903],loss: 0.004
# epoch : [129,4003],loss: 0.004
# epoch : [129,4103],loss: 0.004
# epoch : [129,4203],loss: 0.004
# epoch : [129,4303],loss: 0.004
# epoch : [129,4403],loss: 0.004
# epoch : [129,4503],loss: 0.004
# epoch : [129,4603],loss: 0.004
# epoch : [129,4703],loss: 0.004
# epoch : [129,4803],loss: 0.004
# epoch : [129,4903],loss: 0.004
# epoch : [129,5003],loss: 0.004
# epoch : [129,5103],loss: 0.004
# epoch : [129,5203],loss: 0.004
# epoch : [129,5303],loss: 0.004
# epoch : [129,5403],loss: 0.004
# epoch : [129,5503],loss: 0.004
# epoch : [129,5603],loss: 0.004
# epoch : [129,5703],loss: 0.004
# epoch : [129,5803],loss: 0.004
# epoch : [129,5903],loss: 0.004
# epoch : [129,6003],loss: 0.004
# epoch : [129,6103],loss: 0.004
# epoch : [129,6203],loss: 0.004
# epoch : [129,6303],loss: 0.004
# epoch : [130,71],loss: 0.003
# epoch : [130,171],loss: 0.004
# epoch : [130,271],loss: 0.004
# epoch : [130,371],loss: 0.004
# epoch : [130,471],loss: 0.004
# epoch : [130,571],loss: 0.004
# epoch : [130,671],loss: 0.004
# epoch : [130,771],loss: 0.004
# epoch : [130,871],loss: 0.004
# epoch : [130,971],loss: 0.004
# epoch : [130,1071],loss: 0.004
# epoch : [130,1171],loss: 0.004
# epoch : [130,1271],loss: 0.004
# epoch : [130,1371],loss: 0.004
# epoch : [130,1471],loss: 0.004
# epoch : [130,1571],loss: 0.004
# epoch : [130,1671],loss: 0.004
# epoch : [130,1771],loss: 0.004
# epoch : [130,1871],loss: 0.004
# epoch : [130,1971],loss: 0.004
# epoch : [130,2071],loss: 0.004
# epoch : [130,2171],loss: 0.004
# epoch : [130,2271],loss: 0.004
# epoch : [130,2371],loss: 0.004
# epoch : [130,2471],loss: 0.004
# epoch : [130,2571],loss: 0.004
# epoch : [130,2671],loss: 0.004
# epoch : [130,2771],loss: 0.004
# epoch : [130,2871],loss: 0.004
# epoch : [130,2971],loss: 0.004
# epoch : [130,3071],loss: 0.004
# epoch : [130,3171],loss: 0.004
# epoch : [130,3271],loss: 0.004
# epoch : [130,3371],loss: 0.004
# epoch : [130,3471],loss: 0.004
# epoch : [130,3571],loss: 0.004
# epoch : [130,3671],loss: 0.004
# epoch : [130,3771],loss: 0.004
# epoch : [130,3871],loss: 0.004
# epoch : [130,3971],loss: 0.004
# epoch : [130,4071],loss: 0.004
# epoch : [130,4171],loss: 0.004
# epoch : [130,4271],loss: 0.004
# epoch : [130,4371],loss: 0.004
# epoch : [130,4471],loss: 0.004
# epoch : [130,4571],loss: 0.004
# epoch : [130,4671],loss: 0.004
# epoch : [130,4771],loss: 0.004
# epoch : [130,4871],loss: 0.004
# epoch : [130,4971],loss: 0.004
# epoch : [130,5071],loss: 0.004
# epoch : [130,5171],loss: 0.004
# epoch : [130,5271],loss: 0.004
# epoch : [130,5371],loss: 0.004
# epoch : [130,5471],loss: 0.004
# epoch : [130,5571],loss: 0.004
# epoch : [130,5671],loss: 0.004
# epoch : [130,5771],loss: 0.004
# epoch : [130,5871],loss: 0.004
# epoch : [130,5971],loss: 0.004
# epoch : [130,6071],loss: 0.004
# epoch : [130,6171],loss: 0.004
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-0de5e3e0e988> in <module>
#      16         optimizer.step()
#      17
# ---> 18         running_loss += error_mse.item()
#      19         count = count + 1
#      20
#
# KeyboardInterrupt:

# %%
a,b = face_dataset[10000]
a = torch.unsqueeze(a, 0)
a = a.to(device)
c = net(a)

# %%
print(a.size())
# Out:
# torch.Size([1, 1, 64, 64])

# %%
a = a.cpu().detach().numpy()
c = c.cpu().detach().numpy()

# %%
np.shape(a)
# Out:
# (1, 1, 64, 64)

# %%
import cv2 as cv
cv.imwrite('noisy.png',a[0,0,:,:]*255)
cv.imwrite('denoised.png',c[0,0,:,:]*255)
# Out:
# True
